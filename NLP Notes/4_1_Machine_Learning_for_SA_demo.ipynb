# %% [markdown]
# ## Twitter Sentiment Analysis

# %%
import nltk

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from string import punctuation
from nltk.tokenize import word_tokenize
from nltk.stem import LancasterStemmer
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import LancasterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import re
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## Dataset

# %%
from google.colab import drive

### You can get this file from the link: https://nlp.stanford.edu/projects/glove/
### Unzip it and upload any of the 50/ 100/ 200/ 300 dimensional .txt file on your drive
# Note the file path to point to your downloaded/ uploaded GloVe file

drive.mount('/content/drive')
glove_file_path = '/content/drive/MyDrive/NLP CODES June 2025/Session 5/'   ### For COLAB

df = pd.read_csv(glove_file_path + 'training.1600000.processed.noemoticon.csv',
                 delimiter=',', encoding='ISO-8859-1')
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          polarity of tweet   id of the tweet             date of the tweet  \
# 0                         0       1467810672  Mon Apr 06 22:19:49 PDT 2009
# 1                         0       1467810917  Mon Apr 06 22:19:53 PDT 2009
# 2                         0       1467811184  Mon Apr 06 22:19:57 PDT 2009
# 3                         0       1467811193  Mon Apr 06 22:19:57 PDT 2009
# 4                         0       1467811372  Mon Apr 06 22:20:00 PDT 2009
# ...                     ...              ...                           ...
# 1048567                   4       1960186342  Fri May 29 07:33:44 PDT 2009
# 1048568                   4       1960186409  Fri May 29 07:33:43 PDT 2009
# 1048569                   4       1960186429  Fri May 29 07:33:44 PDT 2009
# 1048570                   4       1960186445  Fri May 29 07:33:44 PDT 2009
# 1048571                   4       1960186607  Fri May 29 07:33:45 PDT 2009
#
#             query             user  \
# 0        NO_QUERY    scotthamilton
# 1        NO_QUERY         mattycus
# 2        NO_QUERY          ElleCTF
# 3        NO_QUERY           Karoli
# 4        NO_QUERY         joy_wolf
# ...           ...              ...
# 1048567  NO_QUERY  Madelinedugganx
# 1048568  NO_QUERY     OffRoad_Dude
# 1048569  NO_QUERY         Falchion
# 1048570  NO_QUERY   jonasobsessedx
# 1048571  NO_QUERY        sugababez
#
#                                         text of the tweet
# 0        is upset that he can't update his Facebook by ...
# 1        @Kenichan I dived many times for the ball. Man...
# 2          my whole body feels itchy and like its on fire
# 3        @nationwideclass no, it's not behaving at all....
# 4                            @Kwesidei not the whole crew
# ...                                                    ...
# 1048567           My GrandMa is making Dinenr with my Mum
# 1048568  Mid-morning snack time... A bowl of cheese noo...
# 1048569  @ShaDeLa same here  say it like from the Termi...
# 1048570             @DestinyHope92 im great thaanks  wbuu?
# 1048571               cant wait til her date this weekend
#
# [1048572 rows x 6 columns]

# %%
df.columns = ['Sentiment','id','date','query','user','text']
df.head()
# Out:
#    Sentiment          id                          date     query  \
# 0          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 1          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 2          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 3          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
#
#             user                                               text
# 0  scotthamilton  is upset that he can't update his Facebook by ...
# 1       mattycus  @Kenichan I dived many times for the ball. Man...
# 2        ElleCTF    my whole body feels itchy and like its on fire
# 3         Karoli  @nationwideclass no, it's not behaving at all....
# 4       joy_wolf                      @Kwesidei not the whole crew

# %%
df = df[['Sentiment','text']]

# %%
df.columns
# Out:
# Index(['Sentiment', 'text'], dtype='object')

# %%
df.Sentiment.value_counts()
# Out:
# Sentiment
# 0    799996
# 4    248576
# Name: count, dtype: int64

# %%
df['Sentiment'] = df['Sentiment'].replace({4:1})
df.Sentiment.value_counts()
# Out:
# Sentiment
# 0    799996
# 1    248576
# Name: count, dtype: int64

# %% [markdown]
# * 0 represent Negative sentiment
# * 1 represents Positive sentiment

# %%
df.isna().sum()
# Out:
# Sentiment    0
# text         0
# dtype: int64

# %% [markdown]
# **Inference: The data is unbalanced therfore we will downsample the data to have same count for each sentiment**

# %% [markdown]
# *italicized text*## Downsampling the dataset

# %%
from sklearn.utils import resample

# %%
## majority class 0
df_majority = df[df['Sentiment']==0]
## minority class 1
df_minority = df[df['Sentiment']==1]

# %%
df_minority.shape
# Out:
# (248576, 2)

# %%
# downsample the majority class
df_majority_downsampled = resample(df_majority,
                                 replace=False,
                                 n_samples=len(df_minority),
                                 random_state=1234)

# %%
frames = [df_majority_downsampled, df_minority]

df = pd.concat(frames)
df.head()
# Out:
#         Sentiment                                               text
# 74567           0  Wow slept for almost 12hours. Sleepy me!! Uni ...
# 668722          0  gets bored with an idea too easily ... like tw...
# 286706          0  To my girls - sorry i've been a homebody latel...
# 632911          0  BK once again for the weekend...If it wasnt fo...
# 356735          0  @DonnieWahlberg Now why didn't you do that las...

# %%
df.Sentiment.value_counts()
# Out:
# Sentiment
# 0    248576
# 1    248576
# Name: count, dtype: int64

# %% [markdown]
# [link text](https://)## Data Preprocessing
#
# 1. removing stop words
# 2. removing punctuations
# 3. Stemmer
# 4. removing tags
# 5. removing special characters
# 6. lowercase conversion

# %%
## remove stopwords and punctuation marks
nltk.download('stopwords')
stuff_to_be_removed = list(stopwords.words('english'))+list(punctuation)
stemmer = LancasterStemmer()

corpus = df['text'].tolist()
print(len(corpus))
print(corpus[0])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# 497152
# Wow slept for almost 12hours. Sleepy me!! Uni now, boo! I wanna stay home, drink tea and watch house...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
nltk.download('wordnet')
# %%time
final_corpus = []
final_corpus_joined = []
for i in df.index:

    text = re.sub('[^a-zA-Z]', ' ', df['text'][i])
    #Convert to lowercase
    text = text.lower()
    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)

    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)

    ##Convert to list from string
    text = text.split()

    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text
            if not word in stuff_to_be_removed]
    text1 = " ".join(text)
    final_corpus.append(text)
    final_corpus_joined.append(text1)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %% [markdown]
# #### Storing the cleaned data seperately

# %%
data_cleaned = pd.DataFrame()
data_cleaned["text"] = final_corpus_joined
data_cleaned["Sentiment"] = df["Sentiment"].values

# %%
data_cleaned['Sentiment'].value_counts()
# Out:
# Sentiment
# 0    248576
# 1    248576
# Name: count, dtype: int64

# %%
data_cleaned.head()
# Out:
#                                                 text  Sentiment
# 0  wow slept almost hour sleepy uni boo wanna sta...          0
# 1                 get bored idea easily like twitter          0
# 2  girl sorry homebody lately dont feel well does...          0
# 3                     bk weekend wasnt puppy stay as          0
# 4                  donniewahlberg last night atlanta          0

# %% [markdown]
# ## EDA

# %%
data_eda = pd.DataFrame()
data_eda['text'] = final_corpus
data_eda['Sentiment'] = df["Sentiment"].values
data_eda.head()
# Out:
#                                                 text  Sentiment
# 0  [wow, slept, almost, hour, sleepy, uni, boo, w...          0
# 1          [get, bored, idea, easily, like, twitter]          0
# 2  [girl, sorry, homebody, lately, dont, feel, we...          0
# 3              [bk, weekend, wasnt, puppy, stay, as]          0
# 4             [donniewahlberg, last, night, atlanta]          0

# %%
# Storing positive data seperately
positive = data_eda[data_eda['Sentiment'] == 1]
positive_list = positive['text'].tolist()

# Storing negative data seperately

negative = data_eda[data_eda['Sentiment'] == 0]
negative_list = negative['text'].tolist()

# %%
positive_all = " ".join([word for sent in positive_list for word in sent ])
negative_all = " ".join([word for sent in negative_list for word in sent ])

# %% [markdown]
# #### Word Cloud Positive data

# %%
from wordcloud import WordCloud
WordCloud()
wordcloud = WordCloud(width=2000,
                      height=1000,
                      background_color='#F2EDD7FF',
                      max_words = 100).generate(positive_all)

plt.figure(figsize=(20,30))
plt.imshow(wordcloud)
plt.title("Positive")
plt.show()

# %% [markdown]
# #### Word CLoud Negative data

# %%
from wordcloud import WordCloud
WordCloud()
wordcloud = WordCloud(width=2000,
                      height=1000,
                      background_color='#F2EDD7FF',
                      max_words = 100).generate(negative_all)

plt.figure(figsize=(20,30))
plt.imshow(wordcloud)
plt.title("negative")
plt.show()

# %% [markdown]
# **Inference:**
# * Positive data has words like Thank, love , LOL, Haha ets
# * Negative data has words like work, sad, tired, suck sorry <br>
# Some of the words are still common in both such as Lol, quot

# %% [markdown]
# #### One word count

# %%
def get_count(data):
    dic = {}
    for i in data:
        for j in i:
            if j not in dic:
                dic[j]=1
            else:
                dic[j]+=1

    return(dic)
count_corpus = get_count(positive_list)

# %%
# count_corpus
# Out:
# {'love': 14969,
#  'health': 139,
#  'uandpets': 6,
#  'u': 12448,
#  'guy': 3475,
#  'r': 1829,
#  'best': 3431,
#  'im': 6434,
#  'meeting': 662,
#  'one': 8907,
#  'besties': 40,
#  'tonight': 3642,
#  'cant': 1515,
#  'wait': 4036,
#  'girl': 2891,
#  'talk': 1287,
#  'darealsunisakim': 3,
#  'thanks': 11375,
#  'twitter': 7193,
#  'add': 770,
#  'sunisa': 1,
#  'got': 8267,
#  'meet': 1108,
#  'hin': 5,
#  'show': 2898,
#  'dc': 143,
#  'area': 193,
#  'sweetheart': 105,
#  'sick': 486,
#  'really': 5887,
#  'cheap': 146,
#  'hurt': 370,
#  'much': 5265,
#  'eat': 1078,
#  'real': 1229,
#  'food': 1170,
#  'plus': 392,
#  'friend': 4308,
#  'make': 5340,
#  'soup': 177,
#  'lovesbrooklyn': 2,
#  'effect': 131,
#  'everyone': 3105,
#  'productoffear': 1,
#  'tell': 1916,
#  'burst': 24,
#  'laughing': 254,
#  'loud': 172,
#  'making': 1353,
#  'come': 4094,
#  'sulk': 5,
#  'keith': 40,
#  'hill': 279,
#  'thans': 1,
#  'response': 141,
#  'ihad': 3,
#  'already': 1667,
#  'find': 1614,
#  'answer': 402,
#  'keepinupwkris': 14,
#  'jealous': 354,
#  'hope': 6486,
#  'great': 8328,
#  'time': 10718,
#  'vega': 303,
#  'like': 12013,
#  'acm': 3,
#  'tommcfly': 570,
#  'ah': 976,
#  'congrats': 967,
#  'mr': 704,
#  'fletcher': 18,
#  'finally': 2434,
#  'joining': 105,
#  'e': 1137,
#  'voip': 7,
#  'responded': 30,
#  'stupid': 354,
#  'cat': 553,
#  'helping': 233,
#  'type': 285,
#  'forgive': 60,
#  'error': 62,
#  'crazy': 909,
#  'day': 19789,
#  'school': 2639,
#  'hour': 2500,
#  'straiiight': 1,
#  'watch': 2565,
#  'spencerpratt': 38,
#  'told': 585,
#  'ha': 1457,
#  'happy': 8155,
#  'birthday': 2343,
#  'jb': 137,
#  'naughtyhaughty': 3,
#  'forget': 548,
#  'two': 1540,
#  'half': 768,
#  'men': 372,
#  'nileyjileyluver': 1,
#  'haha': 6390,
#  'worry': 793,
#  'get': 11490,
#  'hang': 496,
#  'soundwav': 1,
#  'least': 1241,
#  'feeling': 1439,
#  'lost': 678,
#  'may': 1777,
#  'cause': 737,
#  'many': 1276,
#  'later': 2009,
#  'usual': 266,
#  'night': 8043,
#  'addicting': 59,
#  'lutheranlucciol': 1,
#  'sure': 2907,
#  'dm': 430,
#  'post': 1338,
#  'link': 922,
#  'video': 1692,
#  'lt': 3335,
#  'lol': 10741,
#  'gt': 1110,
#  'miss': 1835,
#  'better': 3898,
#  'permission': 21,
#  'blessing': 144,
#  'first': 3004,
#  'added': 319,
#  'tweetie': 194,
#  'new': 7882,
#  'iphone': 619,
#  'michellardi': 1,
#  'know': 8450,
#  'think': 6485,
#  'globe': 28,
#  'yeah': 3888,
#  'sana': 17,
#  'gumaling': 1,
#  'na': 318,
#  'ko': 103,
#  'para': 27,
#  'alam': 6,
#  'din': 85,
#  'kung': 24,
#  'makakasama': 1,
#  'ako': 56,
#  'nicolerichie': 67,
#  'picture': 1318,
#  'sweet': 1882,
#  'catching': 223,
#  'email': 790,
#  'rss': 45,
#  'random': 405,
#  'bacn': 2,
#  'cutting': 61,
#  'early': 1480,
#  'pm': 759,
#  'dinner': 1275,
#  'lauraw': 1,
#  'dancing': 321,
#  'around': 1515,
#  'room': 868,
#  'pjs': 28,
#  'jamming': 35,
#  'ipod': 413,
#  'getting': 3385,
#  'dizzy': 13,
#  'well': 7521,
#  'asked': 310,
#  'place': 1170,
#  'peep': 317,
#  'contest': 178,
#  'voting': 86,
#  'anyways': 240,
#  'going': 9424,
#  'bed': 3518,
#  'goodnight': 1521,
#  'dream': 1182,
#  'http': 14800,
#  'twitpic': 4101,
#  'com': 11017,
#  'littlelumen': 2,
#  'walking': 296,
#  'put': 1346,
#  'deposit': 10,
#  'tomorrow': 4485,
#  'followinq': 1,
#  'dachesterfrench': 3,
#  'shud': 55,
#  'tha': 172,
#  'lordpov': 1,
#  'meant': 393,
#  'back': 7359,
#  'quot': 14567,
#  'twittering': 322,
#  'toilet': 56,
#  'cubicle': 13,
#  'somewhere': 244,
#  'aw': 431,
#  'holding': 99,
#  'puppy': 227,
#  'mine': 1043,
#  'cutie': 94,
#  'ijohn': 1,
#  'kitteh': 10,
#  'sleepin': 28,
#  'crotch': 4,
#  'prof': 36,
#  'dramabeats': 9,
#  'agreed': 144,
#  'reaching': 28,
#  'amritsar': 1,
#  'bus': 366,
#  'wagah': 1,
#  'border': 34,
#  'bkite': 33,
#  'fuj': 1,
#  'albinla': 1,
#  'thinking': 1155,
#  'let': 3199,
#  'interview': 417,
#  'famous': 206,
#  'super': 871,
#  'star': 1143,
#  'spend': 362,
#  'family': 1319,
#  'tired': 1401,
#  'gonna': 3149,
#  'didnt': 507,
#  'effing': 89,
#  'throat': 80,
#  'hurting': 37,
#  'ooooohh': 2,
#  'craving': 108,
#  'pina': 14,
#  'colada': 5,
#  'banana': 158,
#  'slushie': 2,
#  'deon': 14,
#  'upload': 189,
#  'di': 103,
#  'indowebster': 1,
#  'dong': 36,
#  'banggggg': 1,
#  'wisdomous': 1,
#  'welcome': 2327,
#  'glad': 2655,
#  'enjoyed': 517,
#  'hawaii': 74,
#  'shellz': 2,
#  'hahaha': 1440,
#  'omg': 1313,
#  'wer': 12,
#  'laughin': 9,
#  'hook': 92,
#  'cuz': 469,
#  'da': 507,
#  'rolll': 1,
#  'ryt': 13,
#  'sheldawg': 1,
#  'sickwiththepen': 2,
#  'awww': 634,
#  'pookie': 7,
#  'feel': 3142,
#  'pray': 213,
#  'bag': 306,
#  'nurse': 44,
#  'yay': 3130,
#  'found': 1266,
#  'cuddle': 78,
#  'buddy': 312,
#  'met': 439,
#  'snob': 13,
#  'bad': 1800,
#  'life': 2804,
#  'go': 9170,
#  'across': 162,
#  'universe': 78,
#  'sleep': 3374,
#  'rehearsal': 83,
#  'annabellee': 1,
#  'dry': 114,
#  'potato': 108,
#  'huh': 339,
#  'jonathanrknight': 282,
#  'hi': 2402,
#  'jon': 179,
#  'hear': 1451,
#  'see': 7948,
#  'cruise': 133,
#  'cannot': 251,
#  'knight': 126,
#  'loved': 957,
#  'long': 2563,
#  'conversation': 198,
#  'mom': 2244,
#  'phone': 1295,
#  'suitelifeofkell': 6,
#  'yayyy': 96,
#  'requested': 17,
#  'herrr': 5,
#  'say': 3846,
#  'practicing': 42,
#  'line': 481,
#  'mannerism': 1,
#  'voice': 423,
#  'upcoming': 68,
#  'feature': 161,
#  'shoot': 328,
#  'probably': 928,
#  'driving': 379,
#  'brock': 6,
#  'read': 1581,
#  'moon': 257,
#  'rd': 262,
#  'enough': 958,
#  'twilight': 360,
#  'series': 268,
#  'today': 9627,
#  'month': 944,
#  'anniversary': 166,
#  'sooooooo': 38,
#  'diana': 53,
#  'dont': 1694,
#  'even': 2145,
#  'tar': 11,
#  'heel': 67,
#  'ncaa': 7,
#  'woot': 373,
#  'bored': 734,
#  'stevecla': 3,
#  'wallpaper': 55,
#  'red': 652,
#  'square': 74,
#  'asking': 296,
#  'pope': 14,
#  'mello': 3,
#  'noticed': 161,
#  'bb': 167,
#  'tryna': 51,
#  'inspired': 138,
#  'thats': 1604,
#  'kourtneykardash': 29,
#  'workout': 203,
#  'ladygaga': 39,
#  'ur': 2496,
#  'hot': 1400,
#  'as': 578,
#  'austin': 98,
#  'annnd': 10,
#  'bob': 125,
#  'purple': 145,
#  'went': 1680,
#  'royal': 50,
#  'color': 239,
#  'way': 4106,
#  'quotablebuffy': 4,
#  'bunch': 234,
#  'buffy': 34,
#  'song': 3005,
#  'faves': 52,
#  'vivian': 3,
#  'nerf': 4,
#  'herder': 2,
#  'faith': 127,
#  'spike': 29,
#  'body': 294,
#  'devunity': 1,
#  'check': 2009,
#  'morning': 7738,
#  'tweetland': 5,
#  'ahead': 357,
#  'uploading': 172,
#  'friendster': 47,
#  'ash': 102,
#  'ct': 57,
#  'pic': 2013,
#  'p': 2916,
#  'noodlebox': 1,
#  'amanda': 128,
#  'una': 20,
#  'avion': 3,
#  'sorrry': 3,
#  'different': 425,
#  'thing': 4099,
#  'kevin': 138,
#  'jonas': 495,
#  'girlfriend': 194,
#  'fuzeb': 1,
#  'serious': 237,
#  'singing': 389,
#  'whoa': 131,
#  'hehe': 1340,
#  'lsd': 2,
#  'maybe': 2183,
#  'j': 863,
#  'k': 1133,
#  'lolol': 52,
#  'loving': 802,
#  'apothecaryjeri': 5,
#  'sicilian': 4,
#  'damn': 770,
#  'pizza': 377,
#  'planet': 116,
#  'chocolate': 658,
#  'milk': 231,
#  'gf': 84,
#  'sutter': 2,
#  'creek': 31,
#  'tour': 514,
#  'old': 1815,
#  'bodycoach': 1,
#  'look': 4164,
#  'cho': 25,
#  'personally': 90,
#  'strawberry': 193,
#  'become': 219,
#  'coach': 75,
#  'soon': 2963,
#  'little': 2668,
#  'fish': 206,
#  'guess': 1493,
#  'live': 1605,
#  'side': 533,
#  'earth': 228,
#  'east': 124,
#  'mesa': 10,
#  'losiento': 1,
#  'paula': 46,
#  'paige': 33,
#  'apart': 108,
#  'sore': 141,
#  'tryout': 42,
#  'failed': 63,
#  'physic': 53,
#  'test': 511,
#  'homo': 18,
#  'keeen': 1,
#  'holiday': 725,
#  'observed': 6,
#  'update': 1068,
#  'alexa': 25,
#  'website': 494,
#  'tinyurl': 1982,
#  'c': 1608,
#  'gzf': 1,
#  'seems': 618,
#  'improving': 25,
#  'leiabox': 2,
#  'totally': 1042,
#  'geeking': 5,
#  'right': 3945,
#  'theragingocean': 2,
#  'bonjour': 29,
#  'spacecowboy': 1,
#  'wish': 2123,
#  'either': 581,
#  'work': 7097,
#  'kid': 1297,
#  'whenever': 124,
#  'want': 4269,
#  'wherever': 48,
#  'rebecca': 52,
#  'brother': 798,
#  'quite': 879,
#  'weird': 467,
#  'drdrew': 3,
#  'give': 1685,
#  'hug': 695,
#  'cookie': 116,
#  'hey': 4421,
#  'take': 2895,
#  'care': 861,
#  'rundown': 3,
#  'wrote': 232,
#  'wall': 212,
#  'correct': 122,
#  'poor': 232,
#  'spelling': 85,
#  'highlighter': 2,
#  'wash': 129,
#  'hardcore': 63,
#  'good': 20273,
#  'tech': 138,
#  'clubzone': 2,
#  'sushi': 161,
#  'mattgalloway': 2,
#  'carlyrush': 1,
#  'suggesting': 10,
#  'bro': 369,
#  'rock': 1216,
#  'jeffswarens': 1,
#  'depends': 123,
#  'version': 364,
#  'thought': 1943,
#  'speak': 292,
#  'ashley': 139,
#  'hand': 654,
#  'still': 4504,
#  'pretty': 2420,
#  'weak': 56,
#  'punch': 63,
#  'anyone': 1035,
#  'yet': 1479,
#  'turn': 563,
#  'knob': 4,
#  'doesnt': 187,
#  'honey': 251,
#  'lurker': 7,
#  'interesting': 804,
#  'saravananp': 2,
#  'b': 1940,
#  'north': 164,
#  'need': 4907,
#  'decide': 152,
#  'aaru': 1,
#  'hithavaru': 1,
#  'ninage': 1,
#  'ee': 34,
#  'moovarolage': 1,
#  'vote': 385,
#  'trstfndbby': 1,
#  'um': 220,
#  'bought': 768,
#  'shit': 614,
#  'korean': 47,
#  'oach': 1,
#  'highest': 25,
#  'quality': 189,
#  'baby': 1655,
#  'paid': 204,
#  'extra': 290,
#  'tag': 112,
#  'sewed': 4,
#  'eating': 1133,
#  'ice': 608,
#  'cream': 545,
#  'topping': 19,
#  'iamdiddy': 129,
#  'telling': 194,
#  'finished': 1328,
#  'crunch': 42,
#  'step': 277,
#  'diddy': 49,
#  'yvonne': 10,
#  'daaang': 1,
#  'possible': 252,
#  'lauruy': 1,
#  'west': 176,
#  'mostly': 169,
#  'san': 189,
#  'jose': 33,
#  'francisco': 27,
#  'nikki': 68,
#  'working': 1891,
#  'bike': 347,
#  'trying': 1427,
#  'recover': 23,
#  'knee': 85,
#  'injury': 22,
#  'marymayblood': 1,
#  'would': 4224,
#  'help': 1859,
#  'unpack': 8,
#  'sat': 329,
#  'afternoon': 785,
#  'shenagians': 1,
#  'team': 539,
#  'awesome': 4576,
#  'listening': 1726,
#  'music': 1956,
#  'chilling': 193,
#  'regret': 64,
#  'done': 2614,
#  'till': 979,
#  'kick': 341,
#  'study': 433,
#  'amp': 8014,
#  'grow': 141,
#  'rich': 114,
#  'wow': 2135,
#  'amazing': 2739,
#  'timeless': 11,
#  'law': 222,
#  'attraction': 17,
#  'program': 127,
#  'bittenbybooks': 4,
#  'oh': 5485,
#  'week': 4071,
#  'though': 2965,
#  'chris': 325,
#  'home': 5068,
#  'summer': 1248,
#  'davidgideon': 2,
#  'ish': 165,
#  'therealjspace': 2,
#  'tweet': 3719,
#  'drinking': 516,
#  'anne': 67,
#  'kay': 105,
#  'determined': 46,
#  'baseball': 110,
#  'year': 2252,
#  'since': 1066,
#  'watched': 883,
#  'sport': 162,
#  'interested': 249,
#  'game': 1663,
#  'beycah': 1,
#  'becca': 25,
#  'missnappyboy': 1,
#  'ohhh': 155,
#  'nkow': 1,
#  'lexington': 5,
#  'ky': 38,
#  'rite': 78,
#  'next': 3052,
#  'seen': 913,
#  'preview': 56,
#  'movie': 2848,
#  'obsessed': 108,
#  'w': 1914,
#  'beyonce': 50,
#  'broad': 13,
#  'nut': 138,
#  'easy': 578,
#  'rider': 34,
#  'fall': 401,
#  'asleep': 407,
#  'miketomalaris': 1,
#  'excited': 2146,
#  'broadcast': 39,
#  'paris': 160,
#  'roubaix': 1,
#  'moment': 553,
#  'missssssssss': 1,
#  'belliestobabies': 1,
#  'people': 3369,
#  'survive': 67,
#  'winter': 138,
#  'without': 698,
#  'jungle': 31,
#  'gym': 497,
#  'jaredleto': 23,
#  'started': 684,
#  'last': 4371,
#  'holidayholiday': 1,
#  'watchin': 258,
#  'greek': 84,
#  'knighty': 8,
#  'medium': 269,
#  'design': 395,
#  'client': 227,
#  'profile': 422,
#  'lame': 181,
#  'stalk': 57,
#  'sexy': 374,
#  'lou': 49,
#  'aww': 944,
#  'another': 2027,
#  'nitey': 15,
#  'nite': 862,
#  'ahh': 480,
#  'kinda': 764,
#  'nervous': 138,
#  'til': 489,
#  'planning': 317,
#  'whatever': 401,
#  'happier': 87,
#  'hopin': 17,
#  'fb': 450,
#  'store': 448,
#  'missvic': 1,
#  'mean': 1589,
#  'jimmyeatworld': 5,
#  'www': 2017,
#  'deezer': 3,
#  'track': 370,
#  'urbanthai': 1,
#  'thank': 5126,
#  'pamfr': 1,
#  'pam': 40,
#  'yes': 4080,
#  'short': 613,
#  'struggle': 21,
#  'choice': 272,
#  'every': 1127,
#  'hmm': 513,
#  'lot': 2589,
#  'course': 1047,
#  'late': 1163,
#  'reading': 1041,
#  'guykawasaki': 14,
#  'follower': 1520,
#  'almost': 1090,
#  'larrycarroll': 1,
#  'nm': 35,
#  'screaming': 64,
#  'wondering': 357,
#  'freakin': 134,
#  'cooool': 18,
#  'renda': 1,
#  'nothing': 1343,
#  'wrong': 580,
#  'caring': 41,
#  'try': 2007,
#  'brissa': 1,
#  'lauren': 105,
#  'jbrotherlove': 1,
#  'story': 637,
#  'enbaldarlingg': 1,
#  'mirror': 61,
#  'looking': 2530,
#  'amandahesser': 1,
#  'neat': 76,
#  'god': 1688,
#  'overitnow': 1,
#  'apologize': 31,
#  'sharing': 311,
#  'spiritual': 27,
#  'general': 108,
#  'public': 153,
#  'leave': 743,
#  'ontario': 15,
#  'spoke': 50,
#  'fam': 296,
#  'japan': 73,
#  'via': 593,
#  'skype': 119,
#  'mo': 222,
#  'nephew': 111,
#  'growing': 115,
#  'lissym': 1,
#  'saw': 1585,
#  'written': 115,
#  'someone': 1326,
#  'spoken': 27,
#  'suck': 593,
#  'mcfly': 353,
#  'loser': 114,
#  'kacimaureen': 1,
#  'holy': 194,
#  'laundry': 176,
#  'woman': 511,
#  'hate': 912,
#  'trainer': 44,
#  'markhoppus': 80,
#  'fucking': 328,
#  'funny': 1638,
#  'setting': 192,
#  'touch': 337,
#  'officially': 302,
#  'nikhilnarayanan': 8,
#  'tvc': 2,
#  'yesterday': 1396,
#  'worked': 316,
#  'could': 2574,
#  'mannies': 1,
#  'peddies': 1,
#  'shut': 208,
#  'fat': 188,
#  'face': 809,
#  'magopus': 1,
#  'ever': 1918,
#  'run': 928,
#  'idea': 1230,
#  'nominating': 1,
#  'beer': 488,
#  'monday': 1481,
#  'never': 2086,
#  'always': 2594,
#  'hopeinhell': 7,
#  'usually': 261,
#  'follows': 88,
#  'special': 606,
#  'luck': 1763,
#  'rest': 866,
#  'cast': 90,
#  'tb': 60,
#  'something': 2138,
#  'leak': 13,
#  'land': 216,
#  'among': 34,
#  'johnhays': 1,
#  'agree': 670,
#  'entirely': 41,
#  'creative': 159,
#  'vibrant': 5,
#  'reason': 530,
#  'izzakizza': 1,
#  'nada': 23,
#  'holla': 89,
#  'hows': 238,
#  'mixtape': 23,
#  'coming': 1612,
#  'aussie': 128,
#  'ali': 87,
#  'yep': 644,
#  'easier': 226,
#  'point': 613,
#  'snarkattack': 8,
#  'freezer': 23,
#  'worthy': 46,
#  'amoir': 2,
#  'given': 160,
#  'scholarly': 4,
#  'attention': 152,
#  'suppose': 176,
#  'set': 662,
#  'eye': 694,
#  'jf': 14,
#  'cupcake': 201,
#  'purrplexa': 1,
#  'wonderful': 1114,
#  'favor': 71,
#  'using': 551,
#  'entire': 145,
#  'english': 476,
#  'language': 132,
#  'use': 1372,
#  'expletive': 2,
#  'mynameisgerard': 1,
#  'saying': 513,
#  'walk': 706,
#  'flippin': 17,
#  'cold': 611,
#  'outside': 781,
#  'ago': 692,
#  'sunny': 864,
#  'raining': 319,
#  'snowing': 15,
#  'sisterpatterson': 1,
#  'ate': 323,
#  'raw': 47,
#  'dough': 30,
#  'tub': 38,
#  'must': 1370,
#  'kindred': 8,
#  'spirit': 131,
#  'internet': 460,
#  'dirty': 126,
#  'nighty': 138,
#  'bloom': 17,
#  'tweetdeck': 234,
#  'facebook': 856,
#  'firestoned': 1,
#  'dude': 800,
#  'surprised': 180,
#  'tweeting': 562,
#  'nsastrasasmita': 1,
#  'figure': 397,
#  'llama': 8,
#  'malcolm': 2,
#  'megan': 72,
#  'fuck': 413,
#  'theatre': 64,
#  'kayotae': 1,
#  'martini': 30,
#  'city': 677,
#  'soo': 629,
#  'spring': 339,
#  'break': 675,
#  'watching': 4031,
#  'moviess': 4,
#  'everyday': 203,
#  'pushplaynick': 3,
#  'grandpa': 43,
#  'chest': 36,
#  'beef': 60,
#  'george': 117,
#  'lopez': 28,
#  'rulesss': 1,
#  'katieporrello': 2,
#  'katie': 115,
#  'heading': 747,
#  'club': 413,
#  'stellar': 23,
#  'homey': 5,
#  'youtube': 823,
#  'v': 964,
#  'cle': 7,
#  'pjsras': 1,
#  'flower': 264,
#  'gone': 563,
#  'peter': 95,
#  'paul': 220,
#  'mary': 144,
#  'fav': 297,
#  'def': 242,
#  'shhhhhhhhhh': 1,
#  'posting': 179,
#  'photo': 1099,
#  'hit': 759,
#  'count': 276,
#  'china': 86,
#  'view': 301,
#  'alone': 317,
#  'came': 810,
#  'appreciate': 456,
#  'lonelybob': 5,
#  'everywhere': 149,
#  'provided': 21,
#  'broadband': 17,
#  'kiddin': 21,
#  'callin': 22,
#  'infinitarchitek': 1,
#  'stee': 1,
#  'hash': 29,
#  'bash': 25,
#  'anyway': 748,
#  'loltothepower': 1,
#  'correction': 48,
#  'badass': 41,
#  'fringe': 40,
#  'procoder': 3,
#  'hmmm': 363,
#  'upto': 22,
#  'ninasplayground': 3,
#  'christmas': 81,
#  'bn': 16,
#  'fun': 5753,
#  'caught': 230,
#  'yrold': 3,
#  'cheating': 22,
#  'reflection': 19,
#  'tv': 1000,
#  'hair': 1147,
#  'blue': 492,
#  'wendy': 44,
#  'bowser': 2,
#  'kind': 940,
#  'word': 1158,
#  'stressing': 14,
#  'math': 318,
#  'uhhh': 17,
#  'mintcool': 1,
#  'uh': 198,
#  'designated': 8,
#  'driver': 118,
#  'pch': 4,
#  'empressyen': 1,
#  'whatcha': 34,
#  'chucklin': 1,
#  'bout': 583,
#  'm': 237,
#  'yen': 13,
#  'ijustine': 34,
#  'augustography': 1,
#  'climbing': 39,
#  'sining': 2,
#  'unc': 15,
#  'prepare': 75,
#  'g': 1198,
#  'keyannaaa': 1,
#  'include': 55,
#  'magic': 242,
#  'fountain': 30,
#  'trip': 866,
#  'boring': 328,
#  'trusty': 6,
#  'book': 1447,
#  'anastasia': 7,
#  'laptop': 364,
#  'ff': 501,
#  'top': 661,
#  'buzzing': 13,
#  'sietar': 1,
#  'pattidigh': 8,
#  'pushing': 51,
#  'boundary': 24,
#  'boy': 1449,
#  'money': 687,
#  'manual': 24,
#  'yoshigi': 1,
#  'terrible': 86,
#  'neck': 79,
#  'ache': 47,
#  'chair': 91,
#  'waiting': 1281,
#  'swopper': 1,
#  'arrive': 103,
#  'juneaurock': 1,
#  'hellz': 8,
#  'definitely': 800,
#  'downloading': 157,
#  'jz': 10,
#  'stinkin': 14,
#  'cute': 1730,
#  'lyndeeezy': 1,
#  'hahah': 374,
#  'blog': 1419,
#  'nice': 5630,
#  'recent': 64,
#  'popular': 98,
#  'listed': 34,
#  'together': 640,
#  'michaelgrainger': 46,
#  ...}

# %%
count_corpus = pd.DataFrame({"word":count_corpus.keys(),"count":count_corpus.values()})
count_corpus = count_corpus.sort_values(by = "count", ascending = False)

# %%
count_corpus
# Out:
#                  word  count
# 485              good  20273
# 84                day  19789
# 0                love  14969
# 181              http  14800
# 196              quot  14567
# ...               ...    ...
# 170962            lpm      1
# 170963     teaforlife      1
# 170964       stormmmo      1
# 170965      schoolioo      1
# 170966  estrellabella      1
#
# [170985 rows x 2 columns]

# %%
import seaborn as sns
plt.figure(figsize = (15,10))
sns.barplot(x = count_corpus["word"][:20], y = count_corpus["count"][:20])
plt.title('one words in positive data')
plt.show()

# %%
def get_count(data):
    dic = {}
    for i in data:
        for j in i:
            if j not in dic:
                dic[j]=1
            else:
                dic[j]+=1

    #dic = dict(sorted(dic.items() , key = lambda x:x[1],reverse=True))
    return(dic)
count_corpus = get_count(negative_list)

# %%
count_corpus = pd.DataFrame({"word":count_corpus.keys(),"count":count_corpus.values()})
count_corpus = count_corpus.sort_values(by = "count", ascending = False)

# %%
import seaborn as sns
plt.figure(figsize = (15,10))
sns.barplot(x = count_corpus["word"][:20], y = count_corpus["count"][:20])
plt.title('one words in negative data')
plt.show()

# %% [markdown]
# **Inference**
# * Positive data has words like good, day, thanks, great, happy
# * Negative data has words like work, miss, sad etc

# %% [markdown]
# ## Classification
# ### Naive bayes for sentiment analysis

# %%
def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

positive_tokens_for_model = get_tweets_for_model(positive_list)
negative_tokens_for_model = get_tweets_for_model(negative_list)

# %%
positive_tokens_for_model
# Out:
# <generator object get_tweets_for_model at 0x7e140dead7e0>

# %%
import random

positive_dataset = [(review_dict, "Positive")
                     for review_dict in positive_tokens_for_model]

negative_dataset = [(review_dict, "Negative")
                     for review_dict in negative_tokens_for_model]
dataset = positive_dataset + negative_dataset

random.shuffle(dataset)

train_data = dataset[:333091]
test_data = dataset[333091:]

# %%
train_data[1]
# Out:
# ({'got': True,
#   'phone': True,
#   'call': True,
#   'ex': True,
#   'boyfriend': True,
#   'weird': True,
#   'even': True,
#   'think': True,
#   'right': True,
#   'ugh': True,
#   'night': True,
#   'much': True,
#   'love': True},
#  'Negative')

# %%
# dataset
# Out:
# [({'mayorsam': True,
#    'tgeisler': True,
#    'thank': True,
#    'followfriday': True,
#    'great': True,
#    'day': True},
#   'Positive'),
#  ({'got': True,
#    'phone': True,
#    'call': True,
#    'ex': True,
#    'boyfriend': True,
#    'weird': True,
#    'even': True,
#    'think': True,
#    'right': True,
#    'ugh': True,
#    'night': True,
#    'much': True,
#    'love': True},
#   'Negative'),
#  ({'found': True, 'interesting': True, 'project': True, 'rac': True},
#   'Positive'),
#  ({'annagabbert': True,
#    'sound': True,
#    'preachery': True,
#    'anything': True,
#    'iphone': True,
#    'amazing': True,
#    'issue': True,
#    'since': True,
#    'firmware': True,
#    'wink': True},
#   'Positive'),
#  ({'got': True,
#    'cupcake': True,
#    'taste': True,
#    'good': True,
#    'especially': True,
#    'screen': True,
#    'keyboard': True},
#   'Positive'),
#  ({'oppcashley': True, 'funnnnn': True}, 'Positive'),
#  ({'babyblueonline': True,
#    'omg': True,
#    'sorry': True,
#    'hear': True,
#    'really': True,
#    'need': True,
#    'talk': True,
#    'someone': True,
#    'always': True,
#    'shoulder': True,
#    'lean': True},
#   'Negative'),
#  ({'joeymcintyre': True,
#    'apparently': True,
#    'chick': True,
#    'camping': True,
#    'already': True,
#    'lol': True},
#   'Positive'),
#  ({'thought': True,
#    'new': True,
#    'wow': True,
#    'squeeze': True,
#    'system': True,
#    'bit': True,
#    'like': True,
#    'fruit': True,
#    'machine': True,
#    'pop': True,
#    'prospect': True,
#    'cash': True,
#    'pocket': True,
#    'cool': True},
#   'Positive'),
#  ({'hate': True,
#    'sat': True,
#    'around': True,
#    'alone': True,
#    'friday': True,
#    'night': True,
#    'big': True,
#    'sad': True,
#    'old': True,
#    'loser': True},
#   'Negative'),
#  ({'summer': True,
#    'almost': True,
#    'yet': True,
#    'dont': True,
#    'want': True,
#    'maybe': True,
#    'cuz': True,
#    'gotten': True,
#    'know': True,
#    'senior': True,
#    'well': True,
#    'biggin': True,
#    'isnt': True,
#    'coming': True,
#    'back': True},
#   'Negative'),
#  ({'happy': True, 'greek': True, 'orthodox': True, 'easter': True},
#   'Positive'),
#  ({'best': True,
#    'part': True,
#    'movie': True,
#    'kirk': True,
#    'total': True,
#    'babe': True},
#   'Positive'),
#  ({'pulang': True,
#    'dr': True,
#    'pim': True,
#    'huhuhu': True,
#    'bye': True,
#    'agaaaa': True},
#   'Negative'),
#  ({'wish': True,
#    'return': True,
#    'work': True,
#    'week': True,
#    'boo': True,
#    'hoo': True},
#   'Negative'),
#  ({'jmarkybb': True,
#    'haha': True,
#    'ut': True,
#    'state': True,
#    'united': True,
#    'utah': True,
#    'rabbie': True,
#    'figured': True,
#    'also': True,
#    'thanks': True},
#   'Positive'),
#  ({'right': True, 'write': True, 'nothing': True, 'work': True}, 'Negative'),
#  ({'cookin': True, 'something': True, 'new': True}, 'Positive'),
#  ({'picseshu': True,
#    'know': True,
#    'fan': True,
#    'joemcnallyphoto': True,
#    'followed': True,
#    'back': True,
#    'responded': True,
#    'tweet': True},
#   'Negative'),
#  ({'buchautor': True,
#    'hi': True,
#    'michael': True,
#    'wow': True,
#    'thanks': True,
#    'kind': True,
#    'word': True,
#    'must': True,
#    'find': True,
#    'love': True,
#    'connection': True,
#    'bg': True,
#    'alone': True},
#   'Positive'),
#  ({'stressed': True, 'school': True}, 'Negative'),
#  ({'cook': True,
#    'depressed': True,
#    'supposed': True,
#    'va': True,
#    'beach': True,
#    'like': True,
#    'week': True,
#    'instead': True,
#    'get': True,
#    'surgery': True},
#   'Negative'),
#  ({'bengoldacre': True,
#    'yeah': True,
#    'green': True,
#    'position': True,
#    'civil': True,
#    'liberty': True,
#    'look': True,
#    'great': True,
#    'bring': True,
#    'vote': True,
#    'woo': True,
#    'science': True,
#    'stance': True},
#   'Negative'),
#  ({'traitor': True,
#    'score': True,
#    'stoppage': True,
#    'time': True,
#    'usa': True,
#    'italy': True,
#    'game': True},
#   'Negative'),
#  ({'brb': True, 'dish': True, 'eeeeeeeewwwwwwww': True}, 'Negative'),
#  ({'want': True,
#    'baguio': True,
#    'retreat': True,
#    'http': True,
#    'plurk': True,
#    'com': True,
#    'p': True,
#    'yrbi': True},
#   'Negative'),
#  ({'ugh': True,
#    'horrible': True,
#    'ending': True,
#    'sandra': True,
#    'kantu': True,
#    'story': True,
#    'prayer': True,
#    'go': True},
#   'Negative'),
#  ({'wish': True, 'home': True, 'dreading': True, 'next': True, 'week': True},
#   'Negative'),
#  ({'alexmcelroy': True,
#    'thanks': True,
#    'alex': True,
#    'starving': True,
#    'eaten': True,
#    'since': True,
#    'noon': True,
#    'take': True,
#    'break': True},
#   'Negative'),
#  ({'ehhhh': True,
#    'feel': True,
#    'bad': True,
#    'dad': True,
#    'didnt': True,
#    'sleep': True,
#    'last': True,
#    'night': True},
#   'Negative'),
#  ({'wtf': True,
#    'confused': True,
#    'someone': True,
#    'one': True,
#    'looked': True,
#    'completely': True,
#    'different': True,
#    'coworkers': True},
#   'Negative'),
#  ({'kiki': True,
#    'miacherry': True,
#    'morning': True,
#    'kik': True,
#    'enjoy': True,
#    'breakfast': True},
#   'Positive'),
#  ({'buhrayaaan': True, 'early': True}, 'Negative'),
#  ({'theappleinsider': True,
#    'later': True,
#    'today': True,
#    'since': True,
#    'planning': True},
#   'Positive'),
#  ({'still': True,
#    'sick': True,
#    'home': True,
#    'flu': True,
#    'trying': True,
#    'several': True,
#    'twitter': True,
#    'desktop': True,
#    'client': True},
#   'Positive'),
#  ({'goodmorning': True,
#    'twitter': True,
#    'wake': True,
#    'ur': True,
#    'ass': True,
#    'something': True,
#    'productive': True,
#    'today': True,
#    'god': True,
#    'bless': True},
#   'Positive'),
#  ({'man': True, 'nothn': True, 'good': True, 'tv': True}, 'Negative'),
#  ({'hi': True,
#    'mia': True,
#    'frm': True,
#    'twitterverse': True,
#    'daughter': True,
#    'sick': True,
#    'since': True,
#    'saturday': True,
#    'ugh': True,
#    'getting': True,
#    'better': True,
#    'still': True,
#    'home': True,
#    'school': True},
#   'Negative'),
#  ({'problem': True, 'sleeping': True}, 'Negative'),
#  ({'oh': True,
#    'relient': True,
#    'k': True,
#    'always': True,
#    'word': True,
#    'need': True},
#   'Positive'),
#  ({'getting': True,
#    'yelled': True,
#    'texting': True,
#    'filming': True,
#    'friend': True,
#    'hate': True},
#   'Negative'),
#  ({'nicoletsang': True,
#    'believe': True,
#    'slut': True,
#    'business': True,
#    'textile': True,
#    'chem': True,
#    'phys': True,
#    'theory': True,
#    'practical': True,
#    'left': True},
#   'Negative'),
#  ({'clarisseaquino': True,
#    'bad': True,
#    'experience': True,
#    'last': True,
#    'visit': True,
#    'thought': True,
#    'gonna': True,
#    'take': True,
#    'away': True,
#    'brace': True,
#    'till': True,
#    'next': True,
#    'month': True},
#   'Negative'),
#  ({'jlkoctober': True, 'im': True, 'trying': True, 'keep': True, 'safe': True},
#   'Positive'),
#  ({'bit': True, 'tongue': True, 'trying': True, 'get': True, 'pj': True},
#   'Negative'),
#  ({'hate': True, 'life': True, 'naples': True, 'god': True, 'help': True},
#   'Negative'),
#  ({'mini': True,
#    'number': True,
#    'back': True,
#    'school': True,
#    'teach': True,
#    'everyone': True,
#    'dinosaur': True,
#    'amp': True,
#    'taking': True,
#    'sunny': True,
#    'walk': True,
#    'city': True},
#   'Positive'),
#  ({'bought': True,
#    'ready': True,
#    'go': True,
#    'back': True,
#    'oxford': True,
#    'ill': True,
#    'see': True,
#    'next': True,
#    'weekend': True,
#    'lebananana': True},
#   'Negative'),
#  ({'handsome': True}, 'Positive'),
#  ({'miss': True,
#    'margarita': True,
#    'mix': True,
#    'becoming': True,
#    'depressed': True,
#    'water': True},
#   'Negative'),
#  ({'chat': True, 'god': True, 'week': True}, 'Negative'),
#  ({'unsung': True,
#    'tale': True,
#    'thanks': True,
#    'yeah': True,
#    'come': True,
#    'thing': True,
#    'far': True,
#    'though': True},
#   'Positive'),
#  ({'morning': True, 'coffee': True, 'fresh': True, 'air': True}, 'Positive'),
#  ({'amp': True, 'thinkk': True, 'doo': True}, 'Positive'),
#  ({'lesleylambert': True, 'glad': True, 'hear': True}, 'Positive'),
#  ({'bout': True,
#    'watch': True,
#    'notorious': True,
#    'cause': True,
#    'feelin': True,
#    'wish': True,
#    'could': True,
#    'eat': True,
#    'something': True,
#    'surgery': True,
#    'tomorrow': True,
#    'food': True,
#    'til': True,
#    'saturday': True},
#   'Negative'),
#  ({'rubbish': True,
#    'day': True,
#    'want': True,
#    'take': True,
#    'wee': True,
#    'man': True,
#    'look': True,
#    'like': True,
#    'gonna': True,
#    'pee': True,
#    'think': True,
#    'need': True,
#    'go': True,
#    'hope': True,
#    'ok': True},
#   'Negative'),
#  ({'jackie': True,
#    'long': True,
#    'hey': True,
#    'big': True,
#    'head': True,
#    'follow': True},
#   'Positive'),
#  ({'watching': True, 'sister': True, 'mariela': True, 'pack': True},
#   'Negative'),
#  ({'broke': True,
#    'thumb': True,
#    'nail': True,
#    'yesterday': True,
#    'today': True,
#    'bent': True,
#    'pinky': True,
#    'break': True,
#    'hurtssss': True},
#   'Negative'),
#  ({'rjakesdub': True, 'good': True, 'morning': True, 'wrinkle': True},
#   'Positive'),
#  ({'raveonstudio': True,
#    'excited': True,
#    'meet': True,
#    'jenn': True,
#    'looking': True,
#    'parkhurst': True,
#    'exchange': True,
#    'right': True,
#    'learning': True,
#    'kind': True,
#    'handy': True,
#    'medical': True,
#    'slang': True},
#   'Positive'),
#  ({'lilylulay': True,
#    'thats': True,
#    'terrible': True,
#    'sorry': True,
#    'hear': True},
#   'Negative'),
#  ({'video': True,
#    'posted': True,
#    'youtube': True,
#    'post': True,
#    'link': True,
#    'tomarow': True,
#    'get': True,
#    'hd': True},
#   'Positive'),
#  ({'jeflux': True, 'totally': True, 'agree': True}, 'Positive'),
#  ({'im': True, 'hungry': True, 'xd': True, 'eat': True}, 'Negative'),
#  ({'english': True,
#    'speechh': True,
#    'funn': True,
#    'topsy': True,
#    'turvy': True,
#    'curvy': True,
#    'dont': True,
#    'ask': True},
#   'Positive'),
#  ({'night': True,
#    'everyone': True,
#    'awesome': True,
#    'show': True,
#    'thanx': True,
#    'new': True,
#    'follower': True},
#   'Positive'),
#  ({'hdcinema': True, 'wow': True, 'right': True}, 'Negative'),
#  ({'joshbuckner': True,
#    'way': True,
#    'long': True,
#    'time': True,
#    'planning': True,
#    'going': True,
#    'sf': True,
#    'end': True,
#    'month': True,
#    'lost': True,
#    'wallet': True},
#   'Negative'),
#  ({'another': True, 'day': True, 'baseball': True}, 'Positive'),
#  ({'chanikin': True,
#    'take': True,
#    'photo': True,
#    'post': True,
#    'da': True,
#    'make': True,
#    'fun': True},
#   'Negative'),
#  ({'sitting': True,
#    'home': True,
#    'chillin': True,
#    'smokin': True,
#    'feel': True,
#    'lot': True,
#    'better': True},
#   'Positive'),
#  ({'light': True,
#    'depression': True,
#    'payed': True,
#    'extra': True,
#    'bill': True,
#    'last': True,
#    'year': True,
#    'tax': True,
#    'must': True,
#    'find': True,
#    'country': True,
#    'lower': True},
#   'Negative'),
#  ({'kissability': True,
#    'luv': True,
#    'scone': True,
#    'especially': True,
#    'warm': True,
#    'pumpkin': True,
#    'one': True,
#    'sound': True,
#    'delicious': True},
#   'Positive'),
#  ({'fighting': True,
#    'bf': True,
#    'well': True,
#    'doesnt': True,
#    'understand': True,
#    'wait': True,
#    'hour': True},
#   'Negative'),
#  ({'pcornqueen': True,
#    'hey': True,
#    'sweet': True,
#    'thanks': True,
#    'well': True,
#    'wish': True},
#   'Positive'),
#  ({'didnt': True, 'win': True, 'itouch': True}, 'Negative'),
#  ({'buddytv': True,
#    'excited': True,
#    'new': True,
#    'pushing': True,
#    'daisy': True,
#    'episode': True,
#    'make': True,
#    'much': True,
#    'worse': True,
#    'finally': True,
#    'gotten': True,
#    'cancellation': True},
#   'Negative'),
#  ({'devincastro': True, 'thing': True, 'much': True, 'starbucks': True},
#   'Positive'),
#  ({'eddieargos': True,
#    'haha': True,
#    'damn': True,
#    'work': True,
#    'stopping': True,
#    'jeff': True,
#    'lewis': True,
#    'love': True},
#   'Negative'),
#  ({'enjoying': True, 'sunshine': True}, 'Positive'),
#  ({'going': True, 'movie': True, 'theater': True}, 'Positive'),
#  ({'feel': True,
#    'sad': True,
#    'since': True,
#    'gavin': True,
#    'need': True,
#    'go': True,
#    'back': True,
#    'philippine': True,
#    'soon': True,
#    'really': True,
#    'breaking': True,
#    'heart': True,
#    'http': True,
#    'twitpic': True,
#    'com': True,
#    'ddhx': True},
#   'Negative'),
#  ({'managed': True,
#    'get': True,
#    'live': True,
#    'stream': True,
#    'going': True,
#    'still': True,
#    'choppy': True,
#    'reason': True,
#    'audio': True,
#    'e': True},
#   'Negative'),
#  ({'starting': True, 'new': True, 'week': True, 'time': True, 'fear': True},
#   'Positive'),
#  ({'today': True, 'eh': True}, 'Negative'),
#  ({'leaving': True,
#    'going': True,
#    'makati': True,
#    'meet': True,
#    'darrel': True,
#    'derick': True,
#    'exciting': True,
#    'seamstress': True,
#    'ugh': True,
#    'gave': True,
#    'problem': True,
#    'love': True,
#    'x': True},
#   'Positive'),
#  ({'foxwhisperer': True,
#    'clean': True,
#    'resulted': True,
#    'soft': True,
#    'top': True,
#    'beaing': True,
#    'soaked': True,
#    'wet': True,
#    'open': True,
#    'dry': True},
#   'Negative'),
#  ({'school': True, 'hour': True, 'home': True}, 'Negative'),
#  ({'emilyoftexas': True,
#    'oooh': True,
#    'emily': True,
#    'texas': True,
#    'one': True,
#    'faves': True},
#   'Positive'),
#  ({'sasha': True,
#    'xx': True,
#    'dont': True,
#    'worry': True,
#    'much': True,
#    'friend': True,
#    'twitter': True,
#    'supporting': True,
#    'ox': True},
#   'Positive'),
#  ({'note': True,
#    'self': True,
#    'thou': True,
#    'shalt': True,
#    'tweet': True,
#    'drive': True,
#    'red': True,
#    'light': True,
#    'swear': True},
#   'Positive'),
#  ({'ashleykohn': True,
#    'aww': True,
#    'thanks': True,
#    'ashley': True,
#    'appreciate': True,
#    'really': True,
#    'liked': True},
#   'Negative'),
#  ({'cardboardcuts': True, 'friend': True, 'mine': True}, 'Positive'),
#  ({'simplyjay': True,
#    'lmaooooo': True,
#    'da': True,
#    'sad': True,
#    'atleast': True,
#    'u': True,
#    'long': True,
#    'ride': True,
#    'back': True,
#    'ny': True,
#    'lol': True,
#    'yikes': True},
#   'Negative'),
#  ({'tyefighter': True, 'green': True, 'black': True}, 'Positive'),
#  ({'tired': True,
#    'wish': True,
#    'follower': True,
#    'fell': True,
#    'unloved': True},
#   'Negative'),
#  ({'oh': True,
#    'know': True,
#    'damn': True,
#    'goop': True,
#    'goopy': True,
#    'chocolate': True,
#    'im': True,
#    'chocoholic': True,
#    'yet': True,
#    'admit': True,
#    'dont': True,
#    'like': True,
#    'cadbury': True,
#    'one': True},
#   'Negative'),
#  ({'ddlovato': True,
#    'grew': True,
#    'yeahh': True,
#    'haha': True,
#    'hi': True,
#    'demi': True,
#    'new': True,
#    'fan': True,
#    'metalhead': True,
#    'love': True,
#    'incredible': True,
#    'like': True,
#    'song': True,
#    'kiss': True,
#    'bye': True},
#   'Positive'),
#  ({'chaddarnell': True,
#    'scare': True,
#    'chad': True,
#    'amazing': True,
#    'sweet': True,
#    'dream': True},
#   'Positive'),
#  ({'back': True,
#    'unpacked': True,
#    'spring': True,
#    'harvest': True,
#    'got': True,
#    'energy': True,
#    'college': True,
#    'tomorrow': True},
#   'Negative'),
#  ({'modeling': True,
#    'sassyword': True,
#    'tashadirect': True,
#    'cathrinefeehely': True,
#    'nansen': True,
#    'ty': True,
#    'following': True,
#    'relax': True,
#    'saturday': True},
#   'Positive'),
#  ({'ops': True,
#    'forgot': True,
#    'tweet': True,
#    'length': True,
#    'pool': True,
#    'yesterday': True,
#    'load': True,
#    'room': True,
#    'improvement': True},
#   'Negative'),
#  ({'priachiongbian': True, 'hell': True, 'yeah': True, 'going': True},
#   'Positive'),
#  ({'lisa': True,
#    'marie': True,
#    'quick': True,
#    'yay': True,
#    'new': True,
#    'friend': True},
#   'Positive'),
#  ({'man': True,
#    'either': True,
#    'get': True,
#    'enough': True,
#    'sleep': True,
#    'much': True},
#   'Negative'),
#  ({'tonesource': True,
#    'good': True,
#    'mood': True,
#    'designing': True,
#    'magazine': True,
#    'getting': True,
#    'bank': True,
#    'holiday': True,
#    'tomorrow': True},
#   'Positive'),
#  ({'dancing': True,
#    'star': True,
#    'take': True,
#    'hand': True,
#    'close': True,
#    'eye': True},
#   'Positive'),
#  ({'going': True,
#    'watch': True,
#    'brand': True,
#    'new': True,
#    'episode': True,
#    'hill': True,
#    'cant': True,
#    'wait': True},
#   'Positive'),
#  ({'princely': True,
#    'want': True,
#    'play': True,
#    'video': True,
#    'game': True,
#    'lately': True},
#   'Negative'),
#  ({'like': True, 'weather': True, 'thunder': True, 'scare': True}, 'Negative'),
#  ({'slg': True,
#    'look': True,
#    'like': True,
#    'able': True,
#    'make': True,
#    'full': True,
#    'time': True,
#    'job': True,
#    'car': True,
#    'gas': True,
#    'guzzler': True},
#   'Negative'),
#  ({'four': True, 'bus': True, 'way': True, 'home': True}, 'Positive'),
#  ({'laurinchen': True}, 'Negative'),
#  ({'look': True, 'good': True, 'cavs': True}, 'Negative'),
#  ({'merak': True,
#    'microsoft': True,
#    'go': True,
#    'around': True,
#    'destroy': True,
#    'net': True,
#    'code': True,
#    'still': True,
#    'living': True,
#    'wild': True},
#   'Positive'),
#  ({'anddh': True,
#    'found': True,
#    'one': True,
#    'wanted': True,
#    'think': True,
#    'buy': True,
#    'lg': True,
#    'arena': True,
#    'today': True,
#    'u': True,
#    'yesterday': True},
#   'Negative'),
#  ({'forgot': True,
#    'phone': True,
#    'home': True,
#    'working': True,
#    'tonight': True},
#   'Negative'),
#  ({'idiotat': True,
#    'pjaficianado': True,
#    'th': True,
#    'nks': True,
#    'follow': True,
#    'dammitdao': True,
#    'idiot': True},
#   'Positive'),
#  ({'morrigan': True,
#    'hug': True,
#    'need': True,
#    'get': True,
#    'blfc': True,
#    'backed': True,
#    'yesterday': True,
#    'sarmy': True,
#    'drama': True,
#    'time': True},
#   'Negative'),
#  ({'stuck': True,
#    'work': True,
#    'worried': True,
#    'dad': True,
#    'amp': True,
#    'little': True,
#    'pissed': True,
#    'find': True,
#    'need': True,
#    'bypass': True},
#   'Negative'),
#  ({'bummed': True,
#    'gonna': True,
#    'miss': True,
#    'ignitephx': True,
#    'home': True,
#    'flu': True},
#   'Negative'),
#  ({'dap': True,
#    'ohh': True,
#    'watching': True,
#    'best': True,
#    'friend': True,
#    'wedding': True,
#    'sad': True},
#   'Negative'),
#  ({'misscaseyb': True, 'email': True, 'tonight': True}, 'Positive'),
#  ({'one': True, 'talking': True}, 'Negative'),
#  ({'mattycus': True, 'yes': True}, 'Negative'),
#  ({'two': True,
#    'guy': True,
#    'saying': True,
#    'one': True,
#    'thing': True,
#    'order': True,
#    'trend': True},
#   'Negative'),
#  ({'jazzyunknown': True, 'houston': True, 'bby': True}, 'Positive'),
#  ({'want': True, 'goto': True, 'work': True, 'today': True}, 'Negative'),
#  ({'dannymcfly': True, 'hey': True}, 'Positive'),
#  ({'might': True,
#    'ignore': True,
#    'twitter': True,
#    'rest': True,
#    'week': True,
#    'e': True,
#    'stuff': True,
#    'making': True,
#    'really': True,
#    'sad': True,
#    'decided': True,
#    'going': True},
#   'Negative'),
#  ({'jmcewan': True,
#    'donniewahlberg': True,
#    'nervous': True,
#    'gonna': True,
#    'give': True,
#    'ya': True,
#    'full': True,
#    'service': True,
#    'minus': True,
#    'stay': True,
#    'w': True,
#    'baby': True},
#   'Negative'),
#  ({'flash': True, 'homework': True, 'run': True, 'though': True, 'mile': True},
#   'Positive'),
#  ({'roommate': True,
#    'annoys': True,
#    'necessary': True,
#    'show': True,
#    'weird': True,
#    'cooking': True,
#    'sticky': True,
#    'rice': True,
#    'egg': True,
#    'veg': True,
#    'cheese': True,
#    'wtf': True,
#    'u': True,
#    'dont': True,
#    'eat': True},
#   'Negative'),
#  ({'ddlovato': True, 'spanish': True}, 'Positive'),
#  ({'tried': True,
#    'looking': True,
#    'forward': True,
#    'watchingca': True,
#    'double': True,
#    'episode': True,
#    'john': True,
#    'kate': True,
#    'evening': True,
#    'best': True,
#    'friend': True},
#   'Positive'),
#  ({'jimmyvo': True,
#    'hahahah': True,
#    'somehow': True,
#    'think': True,
#    'pete': True,
#    'go': True,
#    'along': True,
#    'want': True,
#    'see': True,
#    'world': True,
#    'record': True,
#    'broken': True,
#    'fast': True,
#    'host': True,
#    'shut': True,
#    'co': True},
#   'Positive'),
#  ({'still': True, 'tuneless': True, 'dirge': True}, 'Negative'),
#  ({'go': True,
#    'bed': True,
#    'great': True,
#    'day': True,
#    'left': True,
#    'meet': True,
#    'joy': True,
#    'life': True},
#   'Positive'),
#  ({'neck': True, 'gone': True, 'hard': True}, 'Negative'),
#  ({'already': True, 'packing': True, 'sunday': True}, 'Negative'),
#  ({'argh': True, 'opened': True, 'crisp': True, 'upside': True, 'hate': True},
#   'Negative'),
#  ({'sarahhr': True,
#    'guess': True,
#    'listening': True,
#    'quot': True,
#    'read': True,
#    'poker': True,
#    'face': True,
#    'gonna': True,
#    'miss': True,
#    'thaatt': True},
#   'Negative'),
#  ({'sad': True, 'mgonewild': True}, 'Negative'),
#  ({'health': True, 'food': True, 'suck': True}, 'Negative'),
#  ({'hear': True, 'chitra': True, 'awaresg': True}, 'Positive'),
#  ({'teetee': True,
#    'feeling': True,
#    'grand': True,
#    'hun': True,
#    'wee': True,
#    'bit': True,
#    'tired': True,
#    'though': True,
#    'lmao': True,
#    'today': True,
#    'gonna': True,
#    'nice': True,
#    'blue': True,
#    'skes': True,
#    'warm': True,
#    'sun': True,
#    'love': True,
#    'xx': True},
#   'Positive'),
#  ({'alaksir': True,
#    'iyaa': True,
#    'part': True,
#    'time': True,
#    'sambil': True,
#    'kuliah': True,
#    'hoho': True,
#    'juggling': True,
#    'coffee': True,
#    'amp': True,
#    'skripsi': True,
#    'doakan': True,
#    'saya': True},
#   'Positive'),
#  ({'think': True, 'twitter': True, 'hate': True, 'sad': True, 'dayz': True},
#   'Negative'),
#  ({'someone': True, 'talk': True}, 'Negative'),
#  ({'bydls': True,
#    'sorry': True,
#    'hear': True,
#    'understand': True,
#    'refusing': True,
#    'stay': True,
#    'ever': True,
#    'want': True,
#    'chat': True,
#    'spoonie': True},
#   'Negative'),
#  ({'scharleth': True,
#    'eww': True,
#    'doi': True,
#    'make': True,
#    'ur': True,
#    'lol': True,
#    'gross': True,
#    'go': True,
#    'mels': True,
#    'page': True,
#    'look': True,
#    'aj': True,
#    'imma': True,
#    'jack': True,
#    'nigga': True,
#    'eye': True},
#   'Negative'),
#  ({'parasol': True,
#    'right': True,
#    'new': True,
#    'rock': True,
#    'band': True,
#    'game': True,
#    'ac': True,
#    'dc': True,
#    'jean': True,
#    'damn': True,
#    'patch': True,
#    'rocker': True,
#    'wristband': True,
#    'n': True,
#    'sweetie': True},
#   'Positive'),
#  ({'want': True, 'chst': True, 'someone': True}, 'Negative'),
#  ({'hate': True, 'monday': True}, 'Negative'),
#  ({'thecrumb': True,
#    'yeah': True,
#    'need': True,
#    'set': True,
#    'quot': True,
#    'almost': True,
#    'frozen': True,
#    'still': True,
#    'slushy': True,
#    'drinkable': True,
#    'setting': True},
#   'Positive'),
#  ({'retrorewind': True,
#    'hey': True,
#    'dude': True,
#    'take': True,
#    'break': True,
#    'please': True,
#    'help': True,
#    'figure': True,
#    'shoe': True,
#    'cuter': True,
#    'cruise': True,
#    'http': True,
#    'twitpic': True,
#    'com': True,
#    'gre': True,
#    'thx': True},
#   'Positive'),
#  ({'chefbridgette': True, 'yay': True, 'exciting': True}, 'Positive'),
#  ({'gingeralepunch': True,
#    'thought': True,
#    'responded': True,
#    'apology': True,
#    'definitely': True,
#    'feel': True,
#    'like': True,
#    'failure': True,
#    'please': True,
#    'think': True,
#    'ignoring': True},
#   'Negative'),
#  ({'thought': True,
#    'knocked': True,
#    'good': True,
#    'chunk': True,
#    'email': True,
#    'realized': True,
#    'whole': True,
#    'inbox': True,
#    'still': True,
#    'overflowing': True},
#   'Negative'),
#  ({'mcflyharry': True,
#    'oh': True,
#    'danny': True,
#    'dougie': True,
#    'love': True,
#    'think': True,
#    'deal': True,
#    'sweet': True,
#    'life': True,
#    'easy': True},
#   'Negative'),
#  ({'sasherr': True, 'love': True}, 'Positive'),
#  ({'home': True, 'night': True, 'pub': True}, 'Positive'),
#  ({'alchanii': True,
#    'admit': True,
#    'suck': True,
#    'tf': True,
#    'try': True,
#    'actually': True,
#    'get': True,
#    'good': True,
#    'aparently': True,
#    'better': True},
#   'Negative'),
#  ({'pig': True,
#    'farmer': True,
#    'last': True,
#    'dare': True,
#    'say': True,
#    'grunt': True,
#    'http': True,
#    'rt': True,
#    'nu': True,
#    'jq': True},
#   'Positive'),
#  ({'hard': True,
#    'time': True,
#    'keeping': True,
#    'secret': True,
#    'fam': True,
#    'hurry': True,
#    'middle': True,
#    'june': True},
#   'Positive'),
#  ({'snap': True,
#    'forgot': True,
#    'maintenance': True,
#    'day': True,
#    'blerg': True},
#   'Negative'),
#  ({'think': True,
#    'found': True,
#    'qsa': True,
#    'copied': True,
#    'verbiage': True,
#    'website': True,
#    'pasted': True,
#    'response': True,
#    'question': True,
#    'disappointed': True,
#    'word': True},
#   'Negative'),
#  ({'accountant': True,
#    'always': True,
#    'giving': True,
#    'people': True,
#    'hard': True,
#    'time': True},
#   'Negative'),
#  ({'around': True,
#    'geez': True,
#    'time': True,
#    'know': True,
#    'headache': True,
#    'severe': True,
#    'took': True,
#    'med': True,
#    'waiting': True,
#    'relief': True},
#   'Negative'),
#  ({'shylie': True,
#    'hmm': True,
#    'well': True,
#    'explains': True,
#    'lot': True,
#    'thank': True},
#   'Positive'),
#  ({'back': True, 'normal': True, 'hour': True, 'sleep': True}, 'Positive'),
#  ({'anymeans': True,
#    'get': True,
#    'home': True,
#    'safe': True,
#    'hit': True,
#    'u': True,
#    'mayb': True,
#    'b': True,
#    'sleep': True,
#    'layin': True,
#    'comfy': True,
#    'bed': True,
#    'da': True,
#    'warm': True,
#    'house': True,
#    'wait': True,
#    'train': True},
#   'Negative'),
#  ({'heat': True,
#    'unreal': True,
#    'know': True,
#    'going': True,
#    'take': True,
#    'age': True,
#    'fall': True,
#    'asleep': True,
#    'tonight': True},
#   'Negative'),
#  ({'jst': True, 'little': True, 'bit': True, 'caught': True, 'middle': True},
#   'Positive'),
#  ({'today': True, 'good': True, 'day': True, 'tune': True, 'trance': True},
#   'Positive'),
#  ({'min': True,
#    'second': True,
#    'pacquiao': True,
#    'amazing': True,
#    'fight': True,
#    'awesome': True,
#    'hr': True,
#    'sleep': True,
#    'long': True,
#    'sunday': True,
#    'tiring': True,
#    'worth': True,
#    'end': True},
#   'Positive'),
#  ({'nik': True,
#    'kee': True,
#    'dee': True,
#    'goth': True,
#    'belly': True,
#    'dancing': True,
#    'idea': True,
#    'sort': True,
#    'energy': True,
#    'shame': True,
#    'radio': True},
#   'Negative'),
#  ({'frogworth': True,
#    'hey': True,
#    'great': True,
#    'gig': True,
#    'exchange': True,
#    'track': True,
#    'via': True,
#    'ze': True,
#    'emayal': True,
#    'lost': True,
#    'loop': True,
#    'right': True,
#    'still': True,
#    'writing': True,
#    'xx': True},
#   'Positive'),
#  ({'chill': True,
#    'tv': True,
#    'watching': True,
#    'flannel': True,
#    'shirt': True,
#    'wearing': True,
#    'night': True},
#   'Positive'),
#  ({'oh': True, 'man': True, 'hate': True, 'life': True}, 'Negative'),
#  ({'mandyluvsjbx': True,
#    'aw': True,
#    'girl': True,
#    'seriously': True,
#    'sorry': True,
#    'wish': True,
#    'could': True,
#    'something': True,
#    'help': True},
#   'Negative'),
#  ({'ouchie': True,
#    'got': True,
#    'tooth': True,
#    'pulled': True,
#    'today': True,
#    'dry': True,
#    'socket': True,
#    'cry': True},
#   'Negative'),
#  ({'janyssa': True,
#    'thanks': True,
#    'think': True,
#    'give': True,
#    'time': True,
#    'adapt': True,
#    'absorb': True,
#    'hehe': True},
#   'Positive'),
#  ({'want': True, 'keep': True, 'pet': True}, 'Negative'),
#  ({'ddlovato': True, 'demi': True, 'got': True, 'ticket': True, 'today': True},
#   'Positive'),
#  ({'pkbuechel': True,
#    'another': True,
#    'weekend': True,
#    'apartment': True,
#    'move': True,
#    'guess': True,
#    'bachelorette': True,
#    'monday': True},
#   'Negative'),
#  ({'jgirl': True,
#    'read': True,
#    'unless': True,
#    'unlocked': True,
#    'email': True,
#    'fb': True},
#   'Negative'),
#  ({'like': True, 'rain': True, 'much': True}, 'Negative'),
#  ({'artisticlyanne': True,
#    'old': True,
#    'song': True,
#    'like': True,
#    'gnight': True,
#    'amp': True,
#    'goodby': True,
#    'gay': True,
#    'frikn': True},
#   'Negative'),
#  ({'really': True,
#    'bad': True,
#    'reading': True,
#    'somebody': True,
#    'e': True,
#    'mail': True,
#    'get': True,
#    'confused': True,
#    'middle': True,
#    'sentence': True,
#    'read': True,
#    'still': True},
#   'Negative'),
#  ({'alandavies': True,
#    'hey': True,
#    'let': True,
#    'know': True,
#    'completed': True,
#    'h': True,
#    'got': True,
#    'medal': True,
#    'celebrated': True,
#    'champagne': True,
#    'pub': True,
#    'x': True},
#   'Positive'),
#  ({'tommcfly': True,
#    'awe': True,
#    'im': True,
#    'sorry': True,
#    'broke': True,
#    'toe': True,
#    'bite': True,
#    'love': True,
#    'music': True},
#   'Negative'),
#  ({'ylet': True,
#    'go': True,
#    'lakers': True,
#    'pissed': True,
#    'lukewalton': True,
#    'jersey': True,
#    'dirty': True},
#   'Negative'),
#  ({'jordandroid': True,
#    'star': True,
#    'war': True,
#    'day': True,
#    'urgh': True,
#    'gonna': True,
#    'get': True,
#    'video': True},
#   'Positive'),
#  ({'uft': True,
#    'im': True,
#    'tutoring': True,
#    'lil': True,
#    'si': True,
#    'shes': True,
#    'cute': True,
#    'even': True,
#    'though': True,
#    'eighth': True,
#    'grader': True,
#    'p': True},
#   'Positive'),
#  ({'fuck': True, 'going': True, 'nut': True, 'due': True, 'exam': True},
#   'Negative'),
#  ({'amusing': True,
#    'thing': True,
#    'got': True,
#    'second': True,
#    'email': True,
#    'immediately': True,
#    'saying': True,
#    'stuff': True,
#    'shipped': True,
#    'umbrella': True},
#   'Positive'),
#  ({'june': True, 'th': True, 'rio': True, 'abel': True}, 'Positive'),
#  ({'kyelani': True,
#    'trying': True,
#    'find': True,
#    'info': True,
#    'eye': True,
#    'infection': True,
#    'dog': True,
#    'izzie': True,
#    'woke': True,
#    'one': True,
#    'nasty': True,
#    'poor': True,
#    'thing': True},
#   'Negative'),
#  ({'cold': True}, 'Negative'),
#  ({'way': True, 'work': True}, 'Negative'),
#  ({'ice': True,
#    'cold': True,
#    'tau': True,
#    'huay': True,
#    'zui': True,
#    'juz': True,
#    'thing': True,
#    'nd': True,
#    'long': True,
#    'day': True,
#    'serving': True,
#    'u': True,
#    'noe': True,
#    'call': True,
#    'driving': True,
#    'lesson': True,
#    'daytona': True,
#    'anymore': True},
#   'Positive'),
#  ({'ani': True,
#    'trip': True,
#    'bet': True,
#    'fall': True,
#    'asleep': True,
#    'till': True,
#    'like': True,
#    'morning': True,
#    'sorries': True},
#   'Negative'),
#  ({'willduhhbeast': True,
#    'babe': True,
#    'super': True,
#    'excited': True,
#    'magic': True,
#    'play': True,
#    'cavs': True,
#    'ily': True},
#   'Positive'),
#  ({'one': True,
#    'q': True,
#    'people': True,
#    'sit': True,
#    'home': True,
#    'bitch': True,
#    'internet': True,
#    'trust': True,
#    'feel': True,
#    'great': True},
#   'Negative'),
#  ({'hotwords': True,
#    'quitate': True,
#    'eso': True,
#    'mami': True,
#    'buggin': True,
#    'lol': True},
#   'Positive'),
#  ({'sick': True, 'fever': True, 'hadooooh': True, 'annoyed': True},
#   'Negative'),
#  ({'woke': True,
#    'blah': True,
#    'im': True,
#    'soo': True,
#    'tired': True,
#    'didnt': True,
#    'go': True,
#    'bed': True,
#    'til': True},
#   'Negative'),
#  ({'peterrpann': True,
#    'im': True,
#    'embarrassed': True,
#    'last': True,
#    'night': True,
#    'soley': True,
#    'amp': True,
#    'totally': True,
#    'niqueprice': True,
#    'fault': True,
#    'greatest': True,
#    'extent': True},
#   'Negative'),
#  ({'penguindice': True,
#    'dont': True,
#    'know': True,
#    'mean': True,
#    'always': True,
#    'seem': True,
#    'follow': True,
#    'friday': True,
#    'saturday': True,
#    'bout': True},
#   'Negative'),
#  ({'lonerespite': True,
#    'drive': True,
#    'safe': True,
#    'little': True,
#    'worried': True},
#   'Negative'),
#  ({'feliciaday': True,
#    'always': True,
#    'next': True,
#    'time': True,
#    'put': True,
#    'mean': True,
#    'person': True,
#    'place': True,
#    'lot': True,
#    'people': True,
#    'treat': True,
#    'employee': True,
#    'like': True,
#    'dirt': True,
#    'sadly': True},
#   'Negative'),
#  ({'tissietc': True, 'matter': True}, 'Negative'),
#  ({'brooxpulford': True,
#    'quot': True,
#    'juuuuuuuust': True,
#    'dieeeeed': True,
#    'arm': True,
#    'tonight': True,
#    'song': True,
#    'head': True,
#    'morning': True},
#   'Negative'),
#  ({'holliefrinton': True, 'boner': True}, 'Positive'),
#  ({'gearing': True, 'orlando': True}, 'Positive'),
#  ({'cascandar': True, 'september': True, 'october': True}, 'Negative'),
#  ({'new': True,
#    'iphone': True,
#    'way': True,
#    'nh': True,
#    'go': True,
#    'pa': True,
#    'nj': True,
#    'memphis': True,
#    'wtf': True,
#    'fedex': True,
#    'look': True,
#    'like': True,
#    'wont': True,
#    'till': True,
#    'monday': True},
#   'Negative'),
#  ({'swissfairy': True,
#    'thanks': True,
#    'responding': True,
#    'glad': True,
#    'agree': True},
#   'Positive'),
#  ({'wfaaweather': True,
#    'wld': True,
#    'like': True,
#    'rquest': True,
#    'high': True,
#    'instead': True,
#    'morrow': True,
#    'give': True,
#    'teacher': True,
#    'break': True,
#    'field': True,
#    'day': True,
#    'u': True,
#    'pull': True,
#    'string': True,
#    'right': True},
#   'Positive'),
#  ({'today': True,
#    'blog': True,
#    'recipe': True,
#    'yesterday': True,
#    'fun': True,
#    'time': True,
#    'mommy': True,
#    'day': True,
#    'http': True,
#    'bit': True,
#    'ly': True,
#    'orlqw': True},
#   'Positive'),
#  ({'illclairvoyant': True,
#    'think': True,
#    'make': True,
#    'studio': True,
#    'office': True,
#    'someday': True,
#    'home': True},
#   'Positive'),
#  ({'starbucks': True,
#    'first': True,
#    'time': True,
#    'today': True,
#    'skinny': True,
#    'mocha': True,
#    'latte': True,
#    'good': True,
#    'little': True,
#    'much': True,
#    'chocolate': True,
#    'iced': True,
#    'hazelnut': True,
#    'better': True},
#   'Positive'),
#  ({'alyssa': True,
#    'milano': True,
#    'wanted': True,
#    'say': True,
#    'love': True,
#    'work': True,
#    'without': True,
#    'ability': True,
#    'tv': True,
#    'would': True,
#    'worthless': True},
#   'Positive'),
#  ({'mundah': True,
#    'ooooh': True,
#    'say': True,
#    'missed': True,
#    'show': True,
#    'td': True},
#   'Negative'),
#  ({'dislike': True,
#    'vo': True,
#    'let': True,
#    'watch': True,
#    'gossip': True,
#    'girl': True},
#   'Negative'),
#  ({'sleep': True, 'nick': True, 'wake': True, 'talk': True, 'either': True},
#   'Negative'),
#  ({'good': True, 'lol': True}, 'Positive'),
#  ({'please': True, 'follow': True, 'unicorn': True, 'jmmaer': True},
#   'Positive'),
#  ({'oh': True,
#    'itll': True,
#    'interesting': True,
#    'night': True,
#    'drink': True,
#    'gang': True,
#    'followed': True,
#    'class': True},
#   'Positive'),
#  ({}, 'Positive'),
#  ({'feeling': True,
#    'hungry': True,
#    'minted': True,
#    'lamb': True,
#    'chop': True,
#    'taking': True,
#    'long': True,
#    'grill': True},
#   'Negative'),
#  ({'already': True, 'missing': True, 'glastonbury': True}, 'Negative'),
#  ({'loving': True,
#    'lexington': True,
#    'airport': True,
#    'getting': True,
#    'ready': True,
#    'leave': True,
#    'already': True,
#    'looking': True,
#    'forward': True,
#    'return': True},
#   'Positive'),
#  ({'exotic': True, 'damn': True, 'boo': True, 'think': True}, 'Negative'),
#  ({'daisy': True, 'love': True, 'liquor': True}, 'Positive'),
#  ({'got': True,
#    'back': True,
#    'gold': True,
#    'coat': True,
#    'awsome': True,
#    'miss': True,
#    'friend': True,
#    'already': True},
#   'Negative'),
#  ({'taylorswift': True,
#    'love': True,
#    'belong': True,
#    'sooo': True,
#    'good': True,
#    'well': True,
#    'done': True},
#   'Positive'),
#  ({'fuck': True, 'allergy': True, 'hardly': True, 'even': True, 'hear': True},
#   'Negative'),
#  ({'good': True,
#    'morning': True,
#    'tweet': True,
#    'still': True,
#    'raining': True,
#    'rained': True,
#    'yesterday': True,
#    'look': True,
#    'like': True,
#    'today': True,
#    'make': True,
#    'tired': True},
#   'Negative'),
#  ({'amandapalmer': True,
#    'bethofalltrades': True,
#    'oh': True,
#    'poo': True,
#    'missed': True,
#    'mine': True,
#    'anyway': True,
#    'http': True,
#    'twitpic': True,
#    'com': True,
#    'vf': True},
#   'Negative'),
#  ({'pursebuzz': True,
#    'xsparkage': True,
#    'oh': True,
#    'man': True,
#    'love': True,
#    'coffee': True,
#    'drink': True,
#    'give': True,
#    'stomach': True,
#    'ache': True,
#    'cant': True},
#   'Negative'),
#  ({'parquette': True,
#    'know': True,
#    'mean': True,
#    'work': True,
#    'nearly': True,
#    'hr': True,
#    'aftr': True,
#    'rolling': True,
#    'bed': True,
#    'amp': True,
#    'drive': True,
#    'minute': True,
#    'coffee': True,
#    'person': True},
#   'Negative'),
#  ({'omg': True,
#    'mcdonalds': True,
#    'combo': True,
#    'wendys': True,
#    'sundae': True,
#    'puke': True,
#    'material': True},
#   'Negative'),
#  ({'say': True,
#    'http': True,
#    'tinyurl': True,
#    'com': True,
#    'dy': True,
#    'u': True,
#    'level': True,
#    'brute': True,
#    'plurk': True,
#    'p': True,
#    'paxgf': True},
#   'Positive'),
#  ({'dinosuit': True,
#    'kd': True,
#    'year': True,
#    'highlight': True,
#    'summer': True},
#   'Negative'),
#  ({'second': True,
#    'boston': True,
#    'game': True,
#    'finally': True,
#    'full': True,
#    'attention': True},
#   'Positive'),
#  ({'much': True,
#    'fun': True,
#    'last': True,
#    'night': True,
#    'thanks': True,
#    'jacktrash': True,
#    'sim': True,
#    'another': True,
#    'great': True,
#    'show': True},
#   'Positive'),
#  ({'lainyb': True,
#    'tonight': True,
#    'cool': True,
#    'would': True,
#    'nice': True,
#    'cute': True},
#   'Positive'),
#  ({'angela': True, 'xd': True, 'know': True, 'could': True}, 'Positive'),
#  ({'tai': True,
#    'fighter': True,
#    'said': True,
#    'thing': True,
#    'assless': True,
#    'chap': True},
#   'Negative'),
#  ({'birthday': True, 'yay': True}, 'Positive'),
#  ({'get': True,
#    'sub': True,
#    'subway': True,
#    'ur': True,
#    'way': True,
#    'home': True},
#   'Positive'),
#  ({'quick': True,
#    'play': True,
#    'o': True,
#    'impressed': True,
#    'really': True,
#    'like': True,
#    'search': True,
#    'copy': True,
#    'paste': True,
#    'landscape': True,
#    'keyboard': True,
#    'text': True,
#    'forwarding': True,
#    'mm': True},
#   'Negative'),
#  ({'prayin': True,
#    'god': True,
#    'nothing': True,
#    'wrong': True,
#    'pc': True,
#    'everythings': True},
#   'Negative'),
#  ({'zsazsabinks': True, 'invite': True, 'wawa': True}, 'Negative'),
#  ({'fffff': True, 'want': True, 'get': True, 'bed': True}, 'Negative'),
#  ({'making': True,
#    'flashcard': True,
#    'history': True,
#    'listening': True,
#    'taylor': True,
#    'last': True,
#    'night': True,
#    'fun': True},
#   'Positive'),
#  ({'rkipp': True,
#    'gingergibson': True,
#    'would': True,
#    'guess': True,
#    'big': True,
#    'city': True,
#    'start': True,
#    'sorry': True,
#    'de': True,
#    'finger': True,
#    'crossed': True,
#    'king': True,
#    'prussia': True},
#   'Negative'),
#  ({'movie': True}, 'Positive'),
#  ({'isplayer': True, 'died': True, 'sorry': True}, 'Negative'),
#  ({'hollykatie': True,
#    'th': True,
#    'month': True,
#    'noooo': True,
#    'im': True,
#    'america': True},
#   'Negative'),
#  ({'rox': True, 'funn': True, 'amii': True, 'bailey': True}, 'Positive'),
#  ({'anbudan': True,
#    'bala': True,
#    'thalaiva': True,
#    'ithu': True,
#    'interval': True,
#    'wait': True,
#    'quot': True,
#    'subham': True,
#    'climax': True,
#    'nextweek': True},
#   'Positive'),
#  ({'damohopo': True, 'mwah': True, 'thank': True, 'lovely': True, 'x': True},
#   'Positive'),
#  ({'thisromantic': True, 'holiday': True, 'ending': True}, 'Negative'),
#  ({'hey': True, 'guy': True, 'day': True}, 'Positive'),
#  ({'ufc': True,
#    'baby': True,
#    'saturday': True,
#    'night': True,
#    'rashad': True,
#    'evans': True,
#    'gonna': True,
#    'kick': True,
#    'as': True,
#    'hope': True,
#    'bb': True,
#    'playing': True,
#    'live': True},
#   'Positive'),
#  ({'judedeath': True, 'yup': True, 'awesome': True, 'music': True},
#   'Positive'),
#  ({'chillin': True,
#    'home': True,
#    'wit': True,
#    'fam': True,
#    'bam': True,
#    'amp': True,
#    'nisha': True,
#    'watchin': True,
#    'quot': True,
#    'taken': True,
#    'soon': True,
#    'ill': True,
#    'make': True,
#    'tha': True,
#    'day': True,
#    'reply': True},
#   'Positive'),
#  ({'happy': True,
#    'melpulled': True,
#    'nighter': True,
#    'bday': True,
#    'champion': True,
#    'guess': True,
#    'dont': True,
#    'swine': True,
#    'flu': True,
#    'damn': True,
#    'work': True},
#   'Negative'),
#  ({'thirstinkirstin': True, 'quinto': True, 'girl': True}, 'Negative'),
#  ({'ok': True, 'back': True, 'work': True}, 'Negative'),
#  ({'tick': True, 'taking': True, 'long': True, 'time': True}, 'Negative'),
#  ({'going': True,
#    'see': True,
#    'rock': True,
#    'free': True,
#    'anyone': True,
#    'u': True,
#    'want': True,
#    'go': True,
#    'http': True,
#    'tiny': True,
#    'cc': True,
#    'eiqt': True,
#    'info': True},
#   'Positive'),
#  ({'joined': True, 'twitter': True, 'l': True, 'want': True, 'ot': True},
#   'Positive'),
#  ({'dinner': True, 'authentic': True, 'italian': True}, 'Positive'),
#  ({'want': True}, 'Negative'),
#  ({'talk': True, 'tomorrow': True, 'sigh': True, 'sad': True, 'life': True},
#   'Negative'),
#  ({'sorry': True,
#    'said': True,
#    'quot': True,
#    'trying': True,
#    'exploit': True,
#    'mike': True,
#    'sad': True,
#    'loss': True,
#    'today': True,
#    'gain': True,
#    'shame': True,
#    'leave': True,
#    'alone': True,
#    'rip': True},
#   'Negative'),
#  ({'jmftrindade': True,
#    'actually': True,
#    'fogo': True,
#    'de': True,
#    'chao': True,
#    'amazing': True},
#   'Positive'),
#  ({'fryfan': True, 'lol': True, 'pretty': True, 'good': True, 'acting': True},
#   'Positive'),
#  ({'architeuth': True,
#    'wanna': True,
#    'go': True,
#    'bed': True,
#    'nice': True,
#    'fun': True,
#    'police': True},
#   'Negative'),
#  ({'wellington': True,
#    'monet': True,
#    'exhibition': True,
#    'casually': True,
#    'bumped': True,
#    'wayne': True,
#    'brady': True,
#    'hotel': True,
#    'lobby': True,
#    'mega': True,
#    'exciting': True},
#   'Positive'),
#  ({'kyledlc': True, 'yay': True, 'supposed': True}, 'Positive'),
#  ({'cat': True, 'zed': True, 'missing': True, 'day': True}, 'Negative'),
#  ({'fresh': True,
#    'food': True,
#    'fridge': True,
#    'clean': True,
#    'unit': True,
#    'thing': True,
#    'enjoysimplethings': True},
#   'Positive'),
#  ({'fonejacker': True,
#    'haha': True,
#    'know': True,
#    'work': True,
#    'blip': True,
#    'apart': True,
#    'obvious': True,
#    'thanks': True,
#    'reblipping': True,
#    'song': True,
#    'nice': True,
#    'day': True,
#    'xxx': True},
#   'Positive'),
#  ({'kissotaku': True,
#    'ah': True,
#    'go': True,
#    'audio': True,
#    'working': True,
#    'cooool': True},
#   'Positive'),
#  ({'kurioustrina': True,
#    'awww': True,
#    'thanks': True,
#    'calling': True,
#    'sexxxy': True,
#    'thought': True,
#    'forgot': True},
#   'Positive'),
#  ({'gotta': True,
#    'get': True,
#    'back': True,
#    'tiling': True,
#    'work': True,
#    'day': True,
#    'square': True,
#    'foot': True,
#    'far': True,
#    'could': True,
#    'long': True,
#    'road': True,
#    'completion': True},
#   'Negative'),
#  ({'headache': True}, 'Negative'),
#  ({'jeff': True,
#    'ischill': True,
#    'awww': True,
#    'come': True,
#    'bring': True,
#    'one': True},
#   'Positive'),
#  ({'salvareestate': True,
#    'thanks': True,
#    'thought': True,
#    'might': True,
#    'like': True},
#   'Positive'),
#  ({'circegr': True,
#    'good': True,
#    'day': True,
#    'back': True,
#    'btw': True,
#    'u': True,
#    'right': True,
#    'read': True,
#    'xplosion': True,
#    'news': True,
#    'last': True,
#    'night': True},
#   'Positive'),
#  ({'wanna': True, 'work': True, 'today': True}, 'Negative'),
#  ({'horrible': True, 'argument': True, 'mod': True, 'today': True},
#   'Negative'),
#  ({'love': True, 'hotwords': True}, 'Positive'),
#  ({'miss': True,
#    'singing': True,
#    'going': True,
#    'redbox': True,
#    'amp': True,
#    'music': True,
#    'videoke': True,
#    'session': True,
#    'baby': True},
#   'Negative'),
#  ({'lion': True, 'king': True, 'love': True}, 'Negative'),
#  ({'greystonebar': True,
#    'let': True,
#    'know': True,
#    'might': True,
#    'grab': True,
#    'one': True,
#    'drinx': True},
#   'Positive'),
#  ({'dannywood': True,
#    'b': True,
#    'l': True,
#    'e': True,
#    'basic': True,
#    'instruction': True,
#    'leaving': True,
#    'earth': True},
#   'Positive'),
#  ({'starting': True, 'account': True, 'twitter': True}, 'Positive'),
#  ({'tired': True, 'feel': True, 'week': True, 'could': True, 'collapse': True},
#   'Negative'),
#  ({'adriandanganan': True,
#    'clay': True,
#    'aiken': True,
#    'get': True,
#    'autograph': True},
#   'Positive'),
#  ({'silknpearls': True,
#    'thank': True,
#    'recommending': True,
#    'thetommyv': True,
#    'love': True,
#    'funny': True,
#    'get': True,
#    'always': True,
#    'right': True},
#   'Positive'),
#  ({'miss': True, 'bf': True}, 'Negative'),
#  ({'riddle': True, 'say': True, 'iphone': True, 'ideal': True}, 'Positive'),
#  ({'eatin': True,
#    'chinese': True,
#    'food': True,
#    'damn': True,
#    'man': True,
#    'nba': True,
#    'fuck': True},
#   'Negative'),
#  ({'woke': True,
#    'like': True,
#    'hour': True,
#    'agooo': True,
#    'body': True,
#    'let': True,
#    'go': True,
#    'back': True,
#    'bed': True},
#   'Negative'),
#  ({'going': True, 'mall': True, 'movie': True, 'good': True, 'friend': True},
#   'Positive'),
#  ({'gfalcone': True, 'im': True, 'going': True, 'tour': True, 'xx': True},
#   'Negative'),
#  ({'greek': True, 'till': True, 'august': True}, 'Negative'),
#  ({'joined': True, 'twitter': True}, 'Positive'),
#  ({'xxitsaoifebbzxx': True,
#    'know': True,
#    'u': True,
#    'idea': True,
#    'much': True,
#    'stuff': True,
#    'stop': True,
#    'tho': True,
#    'twitter': True,
#    'addictive': True,
#    'hard': True,
#    'x': True},
#   'Negative'),
#  ({'going': True, 'shopping': True, 'sister': True, 'mom': True}, 'Positive'),
#  ({'phatboi': True, 'hey': True, 'yeah': True, 'raining': True}, 'Negative'),
#  ({'keywood': True, 'cool': True, 'come': True, 'naturally': True, 'bo': True},
#   'Positive'),
#  ({'awwww': True,
#    'miss': True,
#    'flake': True,
#    'dog': True,
#    'crapped': True,
#    'n': True,
#    'room': True,
#    'whenever': True,
#    'pissed': True,
#    'lol': True,
#    'yea': True,
#    'ta': True,
#    'go': True,
#    'wanna': True,
#    'walk': True},
#   'Negative'),
#  ({'medium': True, 'exam': True, 'morro': True, 'morning': True, 'gulp': True},
#   'Negative'),
#  ({'nny': True,
#    'looking': True,
#    'home': True,
#    'based': True,
#    'job': True,
#    'would': True,
#    'like': True,
#    'offer': True,
#    'service': True,
#    'please': True,
#    'dm': True,
#    'try': True,
#    'help': True,
#    'find': True,
#    'work': True},
#   'Positive'),
#  ({'fascinated': True,
#    'old': True,
#    'fogy': True,
#    'heart': True,
#    'enjoy': True,
#    'http': True,
#    'twurl': True,
#    'nl': True,
#    'yt': True,
#    'k': True},
#   'Positive'),
#  ({'akmourad': True,
#    'hey': True,
#    'name': True,
#    'caleb': True,
#    'newest': True,
#    'follower': True},
#   'Positive'),
#  ({'hope': True,
#    'still': True,
#    'buy': True,
#    'ticket': True,
#    'see': True,
#    'passion': True,
#    'pit': True,
#    'wed': True,
#    'emo': True,
#    'bad': True,
#    'sold': True,
#    'listening': True,
#    'night': True,
#    'great': True,
#    'band': True},
#   'Negative'),
#  ({'morning': True,
#    'tweet': True,
#    'today': True,
#    'speaking': True,
#    'test': True,
#    'rsbi': True,
#    'missed': True,
#    'haha': True,
#    'lol': True},
#   'Positive'),
#  ({'good': True,
#    'morning': True,
#    'waiting': True,
#    'parent': True,
#    'say': True,
#    'byebye': True,
#    'caus': True,
#    'driving': True,
#    'home': True},
#   'Negative'),
#  ({'good': True, 'day': True, 'today': True}, 'Negative'),
#  ({'shemah': True, 'aww': True, 'know': True, 'look': True, 'good': True},
#   'Positive'),
#  ({'enamoredsoul': True, 'awesome': True}, 'Positive'),
#  ({'durtyolpirate': True,
#    'animal': True,
#    'control': True,
#    'legally': True,
#    'authorized': True,
#    'catch': True,
#    'outside': True,
#    'building': True},
#   'Negative'),
#  ({'bummer': True,
#    'hotaussiegirl': True,
#    'chat': True,
#    'since': True,
#    'hot': True,
#    'like': True,
#    'george': True,
#    'cloony': True},
#   'Negative'),
# ...
#   'Negative'),
#  ({'aakriti': True,
#    'haha': True,
#    'wnts': True,
#    'latest': True,
#    'news': True,
#    'make': True,
#    'intelligent': True,
#    'tooo': True},
#   'Positive'),
#  ({'trying': True,
#    'make': True,
#    'hair': True,
#    'like': True,
#    'mia': True,
#    'wallace': True,
#    'pulp': True,
#    'fiction': True,
#    'working': True},
#   'Negative'),
#  ({'brentcorrigan': True,
#    'thats': True,
#    'awesome': True,
#    'find': True,
#    'actual': True,
#    'profile': True,
#    'though': True,
#    'cand': True,
#    'send': True,
#    'friend': True,
#    'request': True},
#   'Negative'),
#  ({'suai': True,
#    'oh': True,
#    'quot': True,
#    'shooter': True,
#    'good': True,
#    'movie': True,
#    'seen': True,
#    'tho': True,
#    'gotta': True,
#    'put': True,
#    'back': True,
#    'watch': True,
#    'list': True},
#   'Positive'),
#  ({'chrismillerjr': True, 'see': True, 'link': True}, 'Positive'),
#  ({'quiet': True, 'tonight': True, 'one': True, 'msn': True}, 'Negative'),
#  ({'redbullgurl': True,
#    'steak': True,
#    'banana': True,
#    'cream': True,
#    'pie': True,
#    'nice': True,
#    'late': True,
#    'night': True,
#    'snack': True},
#   'Positive'),
#  ({'nicole': True,
#    'x': True,
#    'oh': True,
#    'hiii': True,
#    'cassie': True,
#    'ask': True,
#    'shes': True,
#    'catching': True,
#    'bus': True,
#    'even': True,
#    'though': True,
#    'know': True,
#    'already': True,
#    'lull': True},
#   'Positive'),
#  ({'need': True, 'friend': True, 'follower': True}, 'Negative'),
#  ({'ashleytisdale': True,
#    'totally': True,
#    'rock': True,
#    'love': True,
#    'role': True,
#    'model': True,
#    'give': True,
#    'shout': True,
#    'please': True,
#    'make': True,
#    'day': True},
#   'Positive'),
#  ({'essenceofhealth': True,
#    'um': True,
#    'follow': True,
#    'please': True,
#    'still': True,
#    'trying': True,
#    'figure': True,
#    'twitter': True,
#    'twittering': True},
#   'Positive'),
#  ({'late': True,
#    'night': True,
#    'studdying': True,
#    'wait': True,
#    'tuesday': True},
#   'Negative'),
#  ({'tomeglenn': True,
#    'iphone': True,
#    'game': True,
#    'idea': True,
#    'waiting': True,
#    'code': True,
#    'much': True,
#    'leisure': True,
#    'time': True,
#    'life': True,
#    'long': True,
#    'u': True,
#    'developed': True},
#   'Negative'),
#  ({'getting': True,
#    'ready': True,
#    'work': True,
#    'im': True,
#    'already': True,
#    'sick': True,
#    'hearing': True,
#    'ahh': True,
#    'wanna': True,
#    'sleep': True},
#   'Negative'),
#  ({'putting': True,
#    'picture': True,
#    'flash': True,
#    'drive': True,
#    'well': True,
#    'song': True,
#    'going': True,
#    'computer': True,
#    'cause': True,
#    'laptop': True,
#    'getting': True,
#    'old': True,
#    'broken': True},
#   'Negative'),
#  ({'first': True, 'day': True, 'work': True}, 'Negative'),
#  ({'got': True,
#    'back': True,
#    'shopping': True,
#    'god': True,
#    'told': True,
#    'go': True,
#    'amp': True,
#    'marked': True,
#    'brie': True,
#    'able': True,
#    'pick': True,
#    'best': True,
#    'em': True},
#   'Positive'),
#  ({'bleakey': True,
#    'u': True,
#    'search': True,
#    'ncolimo': True,
#    'user': True,
#    'found': True},
#   'Negative'),
#  ({'steffc': True,
#    'good': True,
#    'fun': True,
#    'whole': True,
#    'crowd': True,
#    'came': True,
#    'watch': True,
#    'sadly': True,
#    'getting': True,
#    'smaller': True,
#    'every': True,
#    'year': True,
#    'shame': True},
#   'Negative'),
#  ({'cutting': True,
#    'wisdom': True,
#    'tooth': True,
#    'killing': True,
#    'mouth': True,
#    'never': True,
#    'hurt': True,
#    'bad': True,
#    'make': True},
#   'Negative'),
#  ({'sirzulu': True,
#    'fly': True,
#    'nice': True,
#    'one': True,
#    'graduating': True,
#    'x': True},
#   'Positive'),
#  ({'froogloid': True,
#    'hrmm': True,
#    'know': True,
#    'anyone': True,
#    'android': True,
#    'phone': True,
#    'chance': True,
#    'play': True},
#   'Negative'),
#  ({'currently': True,
#    'listening': True,
#    'taylor': True,
#    'swift': True,
#    'belong': True,
#    'love': True},
#   'Positive'),
#  ({'tidy': True, 'room': True}, 'Negative'),
#  ({'twitter': True, 'loner': True}, 'Negative'),
#  ({'coffee': True,
#    'bigbrother': True,
#    'downtown': True,
#    'beloved': True,
#    'one': True,
#    'still': True,
#    'sleep': True,
#    'work': True,
#    'http': True,
#    'plurk': True,
#    'com': True,
#    'p': True,
#    'vezsb': True},
#   'Positive'),
#  ({'faithluvhope': True,
#    'sorry': True,
#    'girl': True,
#    'sometimes': True,
#    'people': True,
#    'suck': True,
#    'nothing': True,
#    'go': True,
#    'brush': True,
#    'yo': True,
#    'shoulder': True,
#    'haha': True},
#   'Negative'),
#  ({'good': True, 'day': True, 'spymaster': True}, 'Negative'),
#  ({'crabfisher': True,
#    'glad': True,
#    'liked': True,
#    'feel': True,
#    'free': True,
#    'ask': True,
#    'q': True},
#   'Positive'),
#  ({'mz': True,
#    'glad': True,
#    'liked': True,
#    'yea': True,
#    'mean': True,
#    'thinking': True,
#    'time': True,
#    'haha': True,
#    'good': True,
#    'fun': True},
#   'Positive'),
#  ({'knowwwwwwww': True}, 'Negative'),
#  ({'yay': True, 'hour': True, 'sleep': True}, 'Negative'),
#  ({'make': True, 'phone': True, 'work': True, 'twitter': True, 'fun': True},
#   'Negative'),
#  ({'gotenkslovesme': True,
#    'haha': True,
#    'yeh': True,
#    'lol': True,
#    'maybe': True,
#    'missed': True,
#    'last': True,
#    'roadshow': True,
#    'cause': True,
#    'rain': True},
#   'Negative'),
#  ({'morning': True,
#    'yall': True,
#    'expectation': True,
#    'good': True,
#    'day': True,
#    'listening': True,
#    'quot': True,
#    'run': True,
#    'leona': True,
#    'lewis': True,
#    'http': True,
#    'bit': True,
#    'ly': True,
#    'uqyc': True},
#   'Negative'),
#  ({'lo': True,
#    'ferrigno': True,
#    'ha': True,
#    'cant': True,
#    'get': True,
#    'big': True,
#    'tried': True,
#    'blah': True,
#    'skinny': True,
#    'girl': True,
#    'rule': True,
#    'anyway': True},
#   'Positive'),
#  ({'oh': True,
#    'record': True,
#    'eating': True,
#    'benadryl': True,
#    'grape': True,
#    'flavored': True,
#    'fast': True,
#    'tab': True,
#    'drinking': True,
#    'starbucks': True,
#    'frappucino': True,
#    'disgusting': True,
#    'ewewewew': True,
#    'hahaha': True},
#   'Negative'),
#  ({'psa': True,
#    'anyone': True,
#    'want': True,
#    'listen': True,
#    'music': True,
#    'please': True,
#    'email': True,
#    'mp': True,
#    'link': True,
#    'tonicabrera': True,
#    'gmail': True,
#    'cuz': True,
#    'lose': True},
#   'Positive'),
#  ({'put': True,
#    'ring': True,
#    'take': True,
#    'honeymoon': True,
#    'http': True,
#    'www': True,
#    'traveljunky': True,
#    'com': True,
#    'blip': True,
#    'fm': True,
#    'lbwf': True},
#   'Positive'),
#  ({'hahah': True,
#    'bat': True,
#    'handed': True,
#    'thats': True,
#    'idk': True,
#    'always': True,
#    'wondered': True,
#    'people': True,
#    'left': True,
#    'others': True,
#    'ha': True},
#   'Negative'),
#  ({'jayboo': True,
#    'ugh': True,
#    'really': True,
#    'jealous': True,
#    'need': True,
#    'leave': True,
#    'tmobile': True,
#    'period': True,
#    'phone': True,
#    'suck': True},
#   'Negative'),
#  ({'ugh': True,
#    'hate': True,
#    'pinkeye': True,
#    'even': True,
#    'month': True,
#    'since': True,
#    'last': True,
#    'time': True,
#    'ha': True,
#    'week': True},
#   'Negative'),
#  ({'tomfelton': True, 'aaaaawhh': True, 'cute': True}, 'Positive'),
#  ({'midst': True,
#    'fufilling': True,
#    'destiny': True,
#    'p': True,
#    'never': True,
#    'realized': True,
#    'letting': True,
#    'go': True,
#    'something': True,
#    'possibly': True,
#    'greatest': True,
#    'thing': True},
#   'Positive'),
#  ({'foxtel': True,
#    'hate': True,
#    'show': True,
#    'andy': True,
#    'roddick': True,
#    'match': True,
#    'gah': True},
#   'Negative'),
#  ({'fine': True,
#    'screw': True,
#    'going': True,
#    'get': True,
#    'thai': True,
#    'anyways': True},
#   'Positive'),
#  ({'ankita': True, 'gaba': True, 'ohh': True, 'cool': True}, 'Positive'),
#  ({'thatkevinsmith': True,
#    'husband': True,
#    'big': True,
#    'fan': True,
#    'amp': True,
#    'live': True,
#    'far': True,
#    'away': True,
#    'able': True,
#    'make': True,
#    'show': True,
#    'going': True,
#    'release': True,
#    'dvd': True,
#    'c': True},
#   'Negative'),
#  ({'grace': True,
#    'walk': True,
#    'hip': True,
#    'pain': True,
#    'like': True,
#    'old': True,
#    'person': True,
#    'stupid': True,
#    'mile': True},
#   'Negative'),
#  ({'follower': True, 'could': True, 'get': True, 'exciting': True},
#   'Positive'),
#  ({'came': True,
#    'back': True,
#    'rm': True,
#    'movie': True,
#    'went': True,
#    'go': True,
#    'c': True,
#    'quot': True,
#    'land': True,
#    'lost': True,
#    'wow': True,
#    'funny': True,
#    'wanted': True,
#    'hangover': True,
#    'sold': True},
#   'Negative'),
#  ({'hot': True,
#    'pink': True,
#    'checker': True,
#    'skirt': True,
#    'pyramid': True,
#    'waist': True,
#    'belt': True,
#    'ots': True,
#    'top': True,
#    'cross': True,
#    'choker': True,
#    'black': True,
#    'lace': True,
#    'legging': True,
#    'suede': True,
#    'ankle': True,
#    'boot': True,
#    'plan': True},
#   'Positive'),
#  ({'railwayromance': True,
#    'weird': True,
#    'u': True,
#    'look': True,
#    'nice': True,
#    'today': True,
#    'way': True},
#   'Positive'),
#  ({'kkaannddeerr': True, 'computer': True}, 'Positive'),
#  ({'work': True, 'want': True, 'go': True, 'home': True}, 'Negative'),
#  ({'elisabethtrask': True,
#    'jealous': True,
#    'say': True,
#    'hi': True,
#    'going': True,
#    'miss': True,
#    'training': True,
#    'major': True,
#    'summer': True,
#    'highlight': True},
#   'Negative'),
#  ({'jaydems': True,
#    'hahaha': True,
#    'awesome': True,
#    'hopefully': True,
#    'nice': True,
#    'enough': True,
#    'come': True,
#    'otherwise': True,
#    'really': True,
#    'suck': True,
#    'cock': True},
#   'Positive'),
#  ({'ice': True,
#    'cube': True,
#    'voice': True,
#    'quot': True,
#    'today': True,
#    'good': True,
#    'day': True,
#    'takin': True,
#    'ya': True,
#    'kiss': True,
#    'muah': True,
#    'nite': True},
#   'Positive'),
#  ({'love': True,
#    'army': True,
#    'boy': True,
#    'basic': True,
#    'right': True,
#    'miss': True},
#   'Negative'),
#  ({'iampericles': True,
#    'yes': True,
#    'first': True,
#    'kit': True,
#    'space': True,
#    'kitstronaut': True},
#   'Positive'),
#  ({'emilyalltimelow': True, 'barakatday': True}, 'Negative'),
#  ({'want': True, 'lyric': True, 'let': True, 'beat': True, 'rock': True},
#   'Negative'),
#  ({'bored': True,
#    'cousin': True,
#    'house': True,
#    'raining': True,
#    'much': True},
#   'Negative'),
#  ({'foole': True,
#    'heart': True,
#    'able': True,
#    'change': True,
#    'device': True,
#    'update': True,
#    'setting': True,
#    'text': True,
#    'command': True,
#    'send': True},
#   'Negative'),
#  ({'show': True,
#    'awesome': True,
#    'kitchen': True,
#    'look': True,
#    'someone': True,
#    'killed': True,
#    'camera': True,
#    'phone': True},
#   'Negative'),
#  ({'man': True, 'school': True, 'already': True}, 'Negative'),
#  ({'need': True,
#    'get': True,
#    'follower': True,
#    'hey': True,
#    'even': True,
#    'bother': True,
#    'one': True,
#    'look': True,
#    'x': True,
#    'lip': True,
#    'sealed': True},
#   'Negative'),
#  ({'submitted': True,
#    'form': True,
#    'google': True,
#    'wave': True,
#    'account': True,
#    'wait': True,
#    'try': True,
#    'io': True},
#   'Positive'),
#  ({'sean': True, 'dummiest': True, 'great': True, 'saturday': True},
#   'Positive'),
#  ({'made': True, 'twitter': True, 'confused': True}, 'Negative'),
#  ({'fridayfollow': True,
#    'sparty': True,
#    'thx': True,
#    'ff': True,
#    'last': True,
#    'week': True,
#    'sorry': True,
#    'reply': True,
#    'sooner': True,
#    'articlesbin': True,
#    'sharing': True,
#    'great': True,
#    'info': True,
#    'lovely': True,
#    'day': True},
#   'Positive'),
#  ({'igorcabbab': True,
#    'liked': True,
#    'hindi': True,
#    'faux': True,
#    'rnb': True,
#    'na': True,
#    'pinipilit': True,
#    'nilang': True,
#    'quot': True,
#    'okay': True,
#    'heart': True},
#   'Positive'),
#  ({'cosmotini': True,
#    'good': True,
#    'know': True,
#    'blogging': True,
#    'thing': True,
#    'go': True,
#    'south': True,
#    'job': True,
#    'writing': True,
#    'tongue': True,
#    'twister': True,
#    'p': True},
#   'Positive'),
#  ({'passing': True,
#    'early': True,
#    'river': True,
#    'sound': True,
#    'amazing': True,
#    'cozy': True,
#    'bed': True,
#    'dog': True},
#   'Positive'),
#  ({'got': True,
#    'back': True,
#    'seeing': True,
#    'star': True,
#    'trek': True,
#    'dad': True,
#    'mom': True,
#    'like': True,
#    'super': True,
#    'good': True,
#    'want': True,
#    'watch': True,
#    'show': True,
#    'hot': True,
#    'guy': True},
#   'Negative'),
#  ({'itsbashy': True,
#    'need': True,
#    'get': True,
#    'bb': True,
#    'tweet': True,
#    'go': True,
#    'brix': True,
#    'amp': True,
#    'didnt': True,
#    'see': True,
#    'u': True,
#    'notice': True,
#    'red': True,
#    'nail': True,
#    'bar': True,
#    'sad': True,
#    'time': True},
#   'Negative'),
#  ({'chad': True,
#    'emery': True,
#    'live': True,
#    'metropolis': True,
#    'dear': True,
#    'sparkle': True,
#    'born': True,
#    'country': True},
#   'Negative'),
#  ({'ok': True,
#    'let': True,
#    'get': True,
#    'day': True,
#    'school': True,
#    'left': True},
#   'Positive'),
#  ({'finished': True,
#    'tanning': True,
#    'go': True,
#    'gym': True,
#    'cause': True,
#    'slight': True,
#    'fever': True},
#   'Negative'),
#  ({'ive': True,
#    'bad': True,
#    'headache': True,
#    'like': True,
#    'last': True,
#    'day': True,
#    'go': True,
#    'away': True,
#    'grr': True},
#   'Negative'),
#  ({'e': True,
#    'book': True,
#    'dont': True,
#    'try': True,
#    'open': True,
#    'read': True,
#    'might': True,
#    'virus': True},
#   'Positive'),
#  ({'melanienugent': True,
#    'oh': True,
#    'damn': True,
#    'im': True,
#    'sorry': True,
#    'good': True,
#    'adding': True,
#    'spoiler': True,
#    'cause': True,
#    'blayze': True,
#    'watching': True,
#    'later': True},
#   'Negative'),
#  ({'louiise': True,
#    'well': True,
#    'london': True,
#    'brum': True,
#    'manc': True,
#    'dublin': True,
#    'idk': True,
#    'really': True,
#    'want': True,
#    'go': True},
#   'Negative'),
#  ({'standing': True,
#    'airport': True,
#    'going': True,
#    'anywhere': True,
#    'working': True},
#   'Negative'),
#  ({'still': True, 'got': True, 'lurgy': True, 'boooo': True}, 'Negative'),
#  ({'youssefsarhan': True,
#    'forget': True,
#    'typeface': True,
#    'started': True,
#    'modified': True,
#    'pretty': True,
#    'heavily': True,
#    'much': True,
#    'help': True,
#    'sorry': True},
#   'Negative'),
#  ({'reading': True,
#    'going': True,
#    'sleep': True,
#    'busy': True,
#    'day': True,
#    'tomorrow': True,
#    'lt': True},
#   'Negative'),
#  ({'tnikolaisen': True,
#    'sure': True,
#    'leaving': True,
#    'tomorrow': True,
#    'till': True,
#    'monday': True,
#    'night': True,
#    'tho': True,
#    'start': True,
#    'work': True,
#    'tuesday': True,
#    'anything': True,
#    'know': True,
#    'ill': True,
#    'let': True},
#   'Negative'),
#  ({'sad': True,
#    'de': True,
#    'iphone': True,
#    'g': True,
#    'include': True,
#    'video': True,
#    'camara': True,
#    'option': True,
#    'update': True},
#   'Negative'),
#  ({'day': True, 'full': True, 'baby': True, 'giggle': True}, 'Positive'),
#  ({'thinking': True,
#    'starting': True,
#    'unfollow': True,
#    'friday': True,
#    'folk': True,
#    'think': True,
#    'new': True,
#    'trend': True},
#   'Positive'),
#  ({'letsgoduke': True,
#    'yeah': True,
#    'love': True,
#    'despair': True,
#    'know': True,
#    'trademark': True,
#    'right': True},
#   'Negative'),
#  ({'janeypud': True, 'thank': True, 'much': True, 'maternalhealth': True},
#   'Positive'),
#  ({'musicphreke': True,
#    'yeah': True,
#    'know': True,
#    'make': True,
#    'want': True,
#    'less': True},
#   'Negative'),
#  ({'http': True,
#    'twitpic': True,
#    'com': True,
#    'x': True,
#    'kl': True,
#    'simple': True,
#    'like': True},
#   'Positive'),
#  ({'wait': True, 'call': True, 'apple': True, 'ipod': True, 'broken': True},
#   'Negative'),
#  ({'teamellen': True,
#    'done': True,
#    'fun': True,
#    'guy': True,
#    'building': True,
#    'amazing': True,
#    'memory': True},
#   'Positive'),
#  ...]

# %%
from nltk import classify
from nltk import NaiveBayesClassifier
classifier = NaiveBayesClassifier.train(train_data)

print(" Training Accuracy is:", round(classify.accuracy(classifier, train_data),2)*100)

print("Testing Accuracy is:", round(classify.accuracy(classifier, test_data),2)*100)

print(classifier.show_most_informative_features(10))
# Out:
#  Training Accuracy is: 86.0
# Testing Accuracy is: 77.0
# Most Informative Features
#                     iran = True           Negati : Positi =     93.8 : 1.0
#                  fawcett = True           Negati : Positi =     49.7 : 1.0
#                  unhappy = True           Negati : Positi =     39.0 : 1.0
#              squarespace = True           Negati : Positi =     36.4 : 1.0
#                 hotwords = True           Positi : Negati =     35.0 : 1.0
#              heartbroken = True           Negati : Positi =     34.4 : 1.0
#                   booooo = True           Negati : Positi =     30.4 : 1.0
#             followfriday = True           Positi : Negati =     29.0 : 1.0
#                   farrah = True           Negati : Positi =     27.9 : 1.0
#               devastated = True           Negati : Positi =     27.7 : 1.0
# None

# %% [markdown]
# ### TFIDF for sentiment analysis

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
vector = tfidf.fit_transform(data_cleaned['text'])
y = data_cleaned['Sentiment']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(vector,
                                                    y,
                                                    test_size=0.20,
                                                    random_state=42,
                                                    stratify = y)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression

# %%
def metrics(y_train,y_train_pred,y_test,y_test_pred):
  print("training accuracy = ",round(accuracy_score(y_train,y_train_pred),2)*100)
  ConfusionMatrixDisplay.from_predictions(y_train,y_train_pred,normalize = 'all')
  print(classification_report(y_train,y_train_pred))
  plt.show()

  print("testing accuracy = ",round(accuracy_score(y_test,y_test_pred),2)*100)
  ConfusionMatrixDisplay.from_predictions(y_test,y_test_pred,normalize = 'all')
  print(classification_report(y_test,y_test_pred))
  plt.show()

# %% [markdown]
# ### Multinomial NB

# %%
NB = MultinomialNB()
NB.fit(X_train,y_train)
y_train_pred = NB.predict(X_train)
y_test_pred = NB.predict(X_test)
metrics(y_train,y_train_pred,y_test,y_test_pred)
# Out:
# training accuracy =  85.0
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85    166545
#            1       0.87      0.82      0.85    166546
#
#     accuracy                           0.85    333091
#    macro avg       0.85      0.85      0.85    333091
# weighted avg       0.85      0.85      0.85    333091
# testing accuracy =  76.0
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77     82031
#            1       0.78      0.73      0.75     82030
#
#     accuracy                           0.76    164061
#    macro avg       0.76      0.76      0.76    164061
# weighted avg       0.76      0.76      0.76    164061

# %% [markdown]
# ### Linear SVC

# %%
svc = LinearSVC()
svc.fit(X_train,y_train)
y_train_pred = svc.predict(X_train)
y_test_pred = svc.predict(X_test)
metrics(y_train,y_train_pred,y_test,y_test_pred)
# Out:
# training accuracy =  90.0
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90    166545
#            1       0.90      0.90      0.90    166546
#
#     accuracy                           0.90    333091
#    macro avg       0.90      0.90      0.90    333091
# weighted avg       0.90      0.90      0.90    333091
# testing accuracy =  77.0
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77     82031
#            1       0.76      0.78      0.77     82030
#
#     accuracy                           0.77    164061
#    macro avg       0.77      0.77      0.77    164061
# weighted avg       0.77      0.77      0.77    164061

# %% [markdown]
# ### Logistic regression

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)
metrics(y_train,y_train_pred,y_test,y_test_pred)
# Out:
# training accuracy =  82.0
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82    166545
#            1       0.81      0.84      0.83    166546
#
#     accuracy                           0.82    333091
#    macro avg       0.82      0.82      0.82    333091
# weighted avg       0.82      0.82      0.82    333091
# testing accuracy =  78.0
#               precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77     82031
#            1       0.76      0.80      0.78     82030
#
#     accuracy                           0.78    164061
#    macro avg       0.78      0.78      0.78    164061
# weighted avg       0.78      0.78      0.78    164061

# %% [markdown]
# ## Conclusion
#
# |Model|Training Accuracy|Testing Accuracy|
# |---|---|---|
# |Naive Bayes|86%|76%|
# |Multinomial NB| 85%|76%|
# |linear SVC|90%|77%|
# |Logistic|83%|78%|

# %% [markdown]
# We see that Logistic regression model performs best with least overfitting as compared to other models and has better performance in testing dataset as well
